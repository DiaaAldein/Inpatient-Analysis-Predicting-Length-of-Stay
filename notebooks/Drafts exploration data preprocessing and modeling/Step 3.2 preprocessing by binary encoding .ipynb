# %% [markdown]
# Data Preprocessing
# The main objective of preprocessing is:
# 1. checking data set for irrelavent columns which not serve our prediction of length of stay model and deal with it.
# 2. Selecting & dropping not Adult patients as they treatment may vary alot from adult.
# 3. handling outliers.
# 4. Handling Categorical Variables:
#    1) For ordinal ordinal categorical features
#    2) For nominal categorical features
#       - using binary encoding
# 5. Correlation heatmap after encoding to chech if there are tow features highly correlated to each other & drop one of them.
# 6. Checking for duplication after droping highly correlated features and dropping duplicated features
# 7. saving processed data set in csv file for next modeling step.
#
# About Dataset:
# This dataset is about inpatient discharged from hospitals of state of New York provided by the Dept of Health of New York state for the year of 2015.

# %%
# Importing necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from datasist.structdata import detect_outliers
import category_encoders as ce
from category_encoders import OneHotEncoder
from sklearn.preprocessing import StandardScaler,robust_scale
from sklearn.model_selection import train_test_split
import joblib

# %%
# loading the dataset.
data = pd.read_csv('../data/processed/cleaned_data.csv')

# %%
# getting copy of the data set
# df = data.copy()

# %%
# Geitting Information about the Data
data.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2331584 entries, 0 to 2331583
# Data columns (total 31 columns):
#  #   Column                               Non-Null Count    Dtype
# ---  ------                               --------------    -----
#  0   health_service_area                  2331584 non-null  object
#  1   hospital_county                      2331584 non-null  object
#  2   operating_certificate_number         2331584 non-null  float64
#  3   facility_id                          2331584 non-null  float64
#  4   facility_name                        2331584 non-null  object
#  5   age_group                            2331584 non-null  object
#  6   zip_code__3_digits                   2331584 non-null  int64
#  7   gender                               2331584 non-null  object
#  8   race                                 2331584 non-null  object
#  9   ethnicity                            2331584 non-null  object
#  10  length_of_stay                       2331584 non-null  int64
#  11  type_of_admission                    2331584 non-null  object
#  12  patient_disposition                  2331584 non-null  object
#  13  ccs_diagnosis_code                   2331584 non-null  int64
#  14  ccs_diagnosis_description            2331584 non-null  object
#  15  ccs_procedure_code                   2331584 non-null  int64
#  16  ccs_procedure_description            2331584 non-null  object
#  17  apr_drg_code                         2331584 non-null  int64
#  18  apr_drg_description                  2331584 non-null  object
#  19  apr_mdc_code                         2331584 non-null  int64
#  20  apr_mdc_description                  2331584 non-null  object
#  21  apr_severity_of_illness_code         2331584 non-null  int64
#  22  apr_severity_of_illness_description  2331584 non-null  object
#  23  apr_risk_of_mortality                2331584 non-null  object
#  24  apr_medical_surgical_description     2331584 non-null  object
#  25  payment_typology_1                   2331584 non-null  object
#  26  birth_weight                         2331584 non-null  int64
#  27  emergency_department_indicator       2331584 non-null  object
#  28  total_charges                        2331584 non-null  float64
#  29  total_costs                          2331584 non-null  float64
#  30  over_120_stay                        2331584 non-null  int64
# dtypes: float64(4), int64(9), object(18)
# memory usage: 551.4+ MB

# %%
#checking for duplication in data 
data.duplicated().sum()
# Out:
# 0

# %%
# veiwing the head of the data the first 5 rows
pd.set_option('display.max_columns', None)  # This will display all columns
data.head()
# Out:
#   health_service_area hospital_county  operating_certificate_number  \
# 0          Western NY     Cattaraugus                      401001.0
# 1          Western NY     Cattaraugus                      401001.0
# 2          Western NY     Cattaraugus                      401001.0
# 3          Western NY     Cattaraugus                      401001.0
# 4          Western NY      Chautauqua                      602001.0
#
#    facility_id                  facility_name age_group  zip_code__3_digits  \
# 0         66.0         Olean General Hospital  50 to 69                 147
# 1         66.0         Olean General Hospital  18 to 29                 147
# 2         66.0         Olean General Hospital  30 to 49                 147
# 3         66.0         Olean General Hospital  50 to 69                 147
# 4        103.0  Woman's Christian Association  50 to 69                 147
#
#   gender   race          ethnicity  length_of_stay type_of_admission  \
# 0      F  White  Not Span/Hispanic               5         Emergency
# 1      F  White  Not Span/Hispanic               8         Emergency
# 2      M  White  Not Span/Hispanic               8         Emergency
# 3      F  White  Not Span/Hispanic               4         Emergency
# 4      M  White  Not Span/Hispanic               3         Emergency
#
#   patient_disposition  ccs_diagnosis_code ccs_diagnosis_description  \
# 0   Home or Self Care                 657            Mood disorders
# 1   Home or Self Care                 657            Mood disorders
# 2   Home or Self Care                 657            Mood disorders
# 3   Home or Self Care                 128                    Asthma
# 4   Home or Self Care                  83     Epilepsy; convulsions
#
#    ccs_procedure_code ccs_procedure_description  apr_drg_code  \
# 0                   0                   NO PROC           753
# 1                   0                   NO PROC           753
# 2                   0                   NO PROC           753
# 3                   0                   NO PROC           141
# 4                   0                   NO PROC            53
#
#   apr_drg_description  apr_mdc_code  \
# 0   Bipolar disorders            19
# 1   Bipolar disorders            19
# 2   Bipolar disorders            19
# 3              Asthma             4
# 4             Seizure             1
#
#                                 apr_mdc_description  \
# 0                     Mental Diseases and Disorders
# 1                     Mental Diseases and Disorders
# 2                     Mental Diseases and Disorders
# 3  Diseases and Disorders of the Respiratory System
# 4      Diseases and Disorders of the Nervous System
#
#    apr_severity_of_illness_code apr_severity_of_illness_description  \
# 0                             1                               Minor
# 1                             2                            Moderate
# 2                             1                               Minor
# 3                             1                               Minor
# 4                             2                            Moderate
#
#   apr_risk_of_mortality apr_medical_surgical_description payment_typology_1  \
# 0                 Minor                          Medical           Medicaid
# 1                 Minor                          Medical           Medicaid
# 2                 Minor                          Medical           Medicaid
# 3                 Minor                          Medical           Medicare
# 4              Moderate                          Medical           Medicaid
#
#    birth_weight emergency_department_indicator  total_charges  total_costs  \
# 0             0                              Y        5620.00      4561.28
# 1             0                              Y        7404.18      6933.94
# 2             0                              Y        7931.28      7154.85
# 3             0                              Y       11304.44      4584.11
# 4             0                              Y        8330.50      4361.74
#
#    over_120_stay
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0

# %% [markdown]
# * From the above and by puting the aim of our model in mind we can noticed that:
#
# Not all the feature will serve our aim as we try to make general model could predict patient length of stay regard less of the city or state also as total cost also stay over 120 and chrges comes at the end of stay they don't make sence to keep them. then the following columns not usefull for the aim of this model it is better to be droped: ['health_service_area','hospital_county','operating_certificate_number','facility_id','facility_name','race','ethnicity','zip_code__3_digits','patient_disposition','ccs_diagnosis_code','ccs_procedure_code','apr_drg_code','apr_mdc_code','apr_severity_of_illness_code','payment_typology_1','birth_weight','total_charges','total_costs','over_120_stay']

# %%
# dropping unnecessary columns for the model from data frame
data.drop(['health_service_area','hospital_county','operating_certificate_number','facility_id','facility_name','race','ethnicity','zip_code__3_digits','patient_disposition','ccs_diagnosis_code','ccs_procedure_code','apr_drg_code','apr_mdc_code','apr_severity_of_illness_code','payment_typology_1','birth_weight','total_charges','total_costs','over_120_stay'],axis=1, inplace=True)

# %%
data.head()
# Out:
#   age_group gender  length_of_stay type_of_admission  \
# 0  50 to 69      F               5         Emergency
# 1  18 to 29      F               8         Emergency
# 2  30 to 49      M               8         Emergency
# 3  50 to 69      F               4         Emergency
# 4  50 to 69      M               3         Emergency
#
#   ccs_diagnosis_description ccs_procedure_description apr_drg_description  \
# 0            Mood disorders                   NO PROC   Bipolar disorders
# 1            Mood disorders                   NO PROC   Bipolar disorders
# 2            Mood disorders                   NO PROC   Bipolar disorders
# 3                    Asthma                   NO PROC              Asthma
# 4     Epilepsy; convulsions                   NO PROC             Seizure
#
#                                 apr_mdc_description  \
# 0                     Mental Diseases and Disorders
# 1                     Mental Diseases and Disorders
# 2                     Mental Diseases and Disorders
# 3  Diseases and Disorders of the Respiratory System
# 4      Diseases and Disorders of the Nervous System
#
#   apr_severity_of_illness_description apr_risk_of_mortality  \
# 0                               Minor                 Minor
# 1                            Moderate                 Minor
# 2                               Minor                 Minor
# 3                               Minor                 Minor
# 4                            Moderate              Moderate
#
#   apr_medical_surgical_description emergency_department_indicator
# 0                          Medical                              Y
# 1                          Medical                              Y
# 2                          Medical                              Y
# 3                          Medical                              Y
# 4                          Medical                              Y

# %% [markdown]
# ### 2. Selecting & dropping not Adult patients as they treatment may vary alot from adult.

# %%
# Selecting & dropping not Adult patients as they treatment may vary alot from adult
data[data.age_group == '0 to 17']['age_group'].count()
# Out:
# 342237

# %%
data.drop(data[data.age_group == '0 to 17'].index,axis=0,inplace=True)

# %%
#checking for duplication in data 
data.duplicated().sum()
# Out:
# 1264916

# %%
# Drop duplicates and reset the index
data = data.drop_duplicates().reset_index(drop=True)

# %% [markdown]
# ### 3. handling outliers.

# %%
data.head()
# Out:
#   age_group gender  length_of_stay type_of_admission  \
# 0  50 to 69      F               5         Emergency
# 1  18 to 29      F               8         Emergency
# 2  30 to 49      M               8         Emergency
# 3  50 to 69      F               4         Emergency
# 4  50 to 69      M               3         Emergency
#
#   ccs_diagnosis_description ccs_procedure_description apr_drg_description  \
# 0            Mood disorders                   NO PROC   Bipolar disorders
# 1            Mood disorders                   NO PROC   Bipolar disorders
# 2            Mood disorders                   NO PROC   Bipolar disorders
# 3                    Asthma                   NO PROC              Asthma
# 4     Epilepsy; convulsions                   NO PROC             Seizure
#
#                                 apr_mdc_description  \
# 0                     Mental Diseases and Disorders
# 1                     Mental Diseases and Disorders
# 2                     Mental Diseases and Disorders
# 3  Diseases and Disorders of the Respiratory System
# 4      Diseases and Disorders of the Nervous System
#
#   apr_severity_of_illness_description apr_risk_of_mortality  \
# 0                               Minor                 Minor
# 1                            Moderate                 Minor
# 2                               Minor                 Minor
# 3                               Minor                 Minor
# 4                            Moderate              Moderate
#
#   apr_medical_surgical_description emergency_department_indicator
# 0                          Medical                              Y
# 1                          Medical                              Y
# 2                          Medical                              Y
# 3                          Medical                              Y
# 4                          Medical                              Y

# %%
# visulize outliers using box plot
sns.boxplot(data=data,x='length_of_stay')
# Out:
# <AxesSubplot:xlabel='length_of_stay'>

# %% [markdown]
# * From the above boxplot there outliers above 20 days we can drop the outliers or change there vale to the end of the wisker which is almost 20 days by this way we are going to keep those patient data and point that prediction of 20 days it means 20 and above days.

# %%
# Identify the outliers in the higher range of the values
outliers = data['length_of_stay'] > 20

# %%
# Replace the outliers with 20
data['length_of_stay'] = np.where(outliers, 20, data['length_of_stay'])

# %%
# visulize outliers using box plot
sns.boxplot(data=data,x='length_of_stay')
# Out:
# <AxesSubplot:xlabel='length_of_stay'>

# %%
# taking copy of the data after 
df = data.copy()

# %%
# checking features value counts.
for i in list(df.columns):
    print(i)
    print(df[i].value_counts())
    print("*"*100)
# Out:
# age_group
# 50 to 69       259317
# 70 or Older    258530
# 30 to 49       140970
# 18 to 29        65614
# Name: age_group, dtype: int64
# ****************************************************************************************************
# gender
# F    372420
# M    352011
# Name: gender, dtype: int64
# ****************************************************************************************************
# length_of_stay
# 2     85287
# 3     83246
# 1     75987
# 4     71556
# 20    64834
# 5     59492
# 6     50393
# 7     43454
# 8     34841
# 9     27936
# 10    22994
# 11    19156
# 12    16278
# 13    14721
# 14    13616
# 15    10992
# 16     9155
# 17     7880
# 18     6796
# 19     5817
# Name: length_of_stay, dtype: int64
# ****************************************************************************************************
# type_of_admission
# Emergency        535867
# Elective         108556
# Urgent            73572
# Trauma             5225
# Not Available      1050
# Newborn             161
# Name: type_of_admission, dtype: int64
# ****************************************************************************************************
# ccs_diagnosis_description
# Septicemia (except in labor)                            32901
# Complication of device; implant or graft                25041
# Complications of surgical procedures or medical care    22389
# Congestive heart failure; nonhypertensive               16382
# Diabetes mellitus with complications                    15558
#                                                         ...
# Cataract                                                   30
# Contraceptive and procreative management                   20
# Osteoporosis                                               19
# Female infertility                                          7
# Birth trauma                                                1
# Name: ccs_diagnosis_description, Length: 257, dtype: int64
# ****************************************************************************************************
# ccs_procedure_description
# NO PROC                    122641
# OTHER THERAPEUTIC PRCS      57995
# RESP INTUB/MECH VENTIL      25465
# BLOOD TRANSFUSION           20030
# OT VASC CATH; NOT HEART     14901
#                             ...
# LOWER GI X-RAY                 11
# TYMPANOPLASTY                  10
# MAMMOGRAPHY                     9
# CORONARY THROMBOLYSIS           8
# INJ/LIG ESOPH VARICES           7
# Name: ccs_procedure_description, Length: 232, dtype: int64
# ****************************************************************************************************
# apr_drg_description
# Septicemia & disseminated infections                                  22541
# Heart failure                                                         15167
# Major small & large bowel procedures                                  11348
# Vaginal delivery                                                      11022
# Other digestive system diagnoses                                      10902
#                                                                       ...
# Cleft lip & palate repair                                                72
# Major cardiothoracic repair of heart anomaly                             56
# Extensive 3rd degree burns w skin graft                                  34
# Pancreas transplant                                                      33
# BPD & oth chronic respiratory diseases arising in perinatal period        4
# Name: apr_drg_description, Length: 285, dtype: int64
# ****************************************************************************************************
# apr_mdc_description
# Diseases and Disorders of the Circulatory System                                                        106387
# Diseases and Disorders of the Digestive System                                                           86556
# Diseases and Disorders of the Respiratory System                                                         66847
# Diseases and Disorders of the Nervous System                                                             64801
# Diseases and Disorders of the Musculoskeletal System and Conn Tissue                                     63614
# Infectious and Parasitic Diseases, Systemic or Unspecified Sites                                         45836
# Diseases and Disorders of the Kidney and Urinary Tract                                                   41254
# Mental Diseases and Disorders                                                                            31337
# Diseases and Disorders of the Hepatobiliary System and Pancreas                                          28887
# Pregnancy, Childbirth and the Puerperium                                                                 27300
# Diseases and Disorders of the Skin, Subcutaneous Tissue and Breast                                       23055
# Endocrine, Nutritional and Metabolic Diseases and Disorders                                              21758
# Rehabilitation, Aftercare, Other Factors Influencing Health Status and Other Health Service Contacts     19222
# Poisonings, Toxic Effects, Other Injuries and Other Complications of Treatment                           15981
# Alcohol/Drug Use and Alcohol/Drug Induced Organic Mental Disorders                                       15787
# Diseases and Disorders of Blood, Blood Forming Organs and Immunological Disorders                        14202
# Ear, Nose, Mouth, Throat and Craniofacial Diseases and Disorders                                         13398
# Lymphatic, Hematopoietic, Other Malignancies, Chemotherapy and Radiotherapy                              12573
# Diseases and Disorders of the Female Reproductive System                                                  8684
# Human Immunodeficiency Virus Infections                                                                   6274
# Diseases and Disorders of the Male Reproductive System                                                    3605
# Multiple Significant Trauma                                                                               3379
# Diseases and Disorders of the Eye                                                                         2467
# Burns                                                                                                     1227
# Name: apr_mdc_description, dtype: int64
# ****************************************************************************************************
# apr_severity_of_illness_description
# Moderate    257235
# Major       252784
# Minor       121635
# Extreme      92777
# Name: apr_severity_of_illness_description, dtype: int64
# ****************************************************************************************************
# apr_risk_of_mortality
# Minor       264159
# Moderate    217234
# Major       170152
# Extreme      72886
# Name: apr_risk_of_mortality, dtype: int64
# ****************************************************************************************************
# apr_medical_surgical_description
# Medical     524955
# Surgical    199476
# Name: apr_medical_surgical_description, dtype: int64
# ****************************************************************************************************
# emergency_department_indicator
# Y    477398
# N    247033
# Name: emergency_department_indicator, dtype: int64
# ****************************************************************************************************

# %%
# checking features n unique.
for i in list(df.columns):
    print(i)
    print(df[i].nunique())
    print("*"*100)
# Out:
# age_group
# 4
# ****************************************************************************************************
# gender
# 2
# ****************************************************************************************************
# length_of_stay
# 20
# ****************************************************************************************************
# type_of_admission
# 6
# ****************************************************************************************************
# ccs_diagnosis_description
# 257
# ****************************************************************************************************
# ccs_procedure_description
# 232
# ****************************************************************************************************
# apr_drg_description
# 285
# ****************************************************************************************************
# apr_mdc_description
# 24
# ****************************************************************************************************
# apr_severity_of_illness_description
# 4
# ****************************************************************************************************
# apr_risk_of_mortality
# 4
# ****************************************************************************************************
# apr_medical_surgical_description
# 2
# ****************************************************************************************************
# emergency_department_indicator
# 2
# ****************************************************************************************************

# %% [markdown]
# ### 4. Handling Categorical Variables:
#   1) For ordinal categorical features

# %% [markdown]
# #### First encoding oridinal feature:
# By creating dictionary with ordinal number and maping the dictionary with the ordinal categorical feature

# %%
# age_group:
dict_age_group = {'18 to 29':1, '30 to 49':2, '50 to 69':3, '70 or Older':4}
# maping age goup dictionary
df['age_group'] = df['age_group'].map(dict_age_group)

# %%
df['age_group'].unique()
# Out:
# array([3, 1, 2, 4], dtype=int64)

# %%
# apr_severity_of_illness_description encode by made dictionery for it.
dict_apr_severity_of_illness_description = {'Minor':1, 'Moderate':2, 'Major':3, 'Extreme':4}
df.apr_severity_of_illness_description = df.apr_severity_of_illness_description.map(dict_apr_severity_of_illness_description)
df.apr_severity_of_illness_description.unique()
# Out:
# array([1, 2, 3, 4], dtype=int64)

# %%
# apr_risk_of_mortality:
dict_apr_risk_of_mortality = {'Minor':1, 'Moderate':2, 'Major':3, 'Extreme':4}
df["apr_risk_of_mortality"] = df["apr_risk_of_mortality"].map(dict_apr_risk_of_mortality)
df["apr_risk_of_mortality"].unique()
# Out:
# array([1, 2, 3, 4], dtype=int64)

# %% [markdown]
# ### Second encoding nominal feature:
# * For Features with high cardinality we are going to use Target Encoding (Mean Encoding) then dropping it:
#   - (ccs_diagnosis_description: 257 unique values, ccs_procedure_description: 232, apr_drg_description: 285, apr_mdc_description: 24,  type_of_admission: 6 unique values)
#
#
# * For features with low cardinality we are going to use get dumies to encode it features like:
#
#   - (gender: 2 unique, apr_medical_surgical_description: 2, emergency_department_indicator: 2)

# %% [markdown]
# #### * First high cardinality categorical Features

# %%
# Target Encoding (Mean Encoding) for (ccs_diagnosis_description: 257 unique values:
dict_ccs_diagnosis_description=round(df.groupby('ccs_diagnosis_description')['length_of_stay'].mean(),2).to_dict()
dict_ccs_diagnosis_description
# Out:
# {'Abdominal hernia': 6.35,
#  'Abdominal pain': 4.28,
#  'Acquired foot deformities': 3.87,
#  'Acute and chronic tonsillitis': 2.75,
#  'Acute and unspecified renal failure': 8.86,
#  'Acute bronchitis': 4.15,
#  'Acute cerebrovascular disease': 8.89,
#  'Acute myocardial infarction': 7.51,
#  'Acute posthemorrhagic anemia': 5.47,
#  'Adjustment disorders': 6.15,
#  'Administrative/social admission': 7.91,
#  'Alcohol-related disorders': 7.62,
#  'Allergic reactions': 4.01,
#  'Anal and rectal conditions': 5.27,
#  'Anxiety disorders': 6.37,
#  'Aortic and peripheral arterial embolism or thrombosis': 7.58,
#  'Aortic; peripheral; and visceral artery aneurysms': 7.28,
#  'Appendicitis and other appendiceal conditions': 5.74,
#  'Aspiration pneumonitis; food/vomitus': 9.04,
#  'Asthma': 5.87,
#  'Attention-deficit, conduct, and disruptive behavior disorders': 7.14,
#  'Bacterial infection; unspecified site': 7.41,
#  'Benign neoplasm of uterus': 4.22,
#  'Biliary tract disease': 6.31,
#  'Birth trauma': 2.0,
#  'Blindness and vision defects': 3.04,
#  'Burns': 8.19,
#  'Calculus of urinary tract': 3.99,
#  'Cancer of bladder': 8.01,
#  'Cancer of bone and connective tissue': 7.1,
#  'Cancer of brain and nervous system': 8.15,
#  'Cancer of breast': 5.94,
#  'Cancer of bronchus; lung': 8.41,
#  'Cancer of cervix': 5.62,
#  'Cancer of colon': 9.35,
#  'Cancer of esophagus': 9.05,
#  'Cancer of head and neck': 8.88,
#  'Cancer of kidney and renal pelvis': 6.57,
#  'Cancer of liver and intrahepatic bile duct': 7.02,
#  'Cancer of other GI organs; peritoneum': 8.66,
#  'Cancer of other female genital organs': 5.66,
#  'Cancer of other male genital organs': 5.65,
#  'Cancer of other urinary organs': 5.92,
#  'Cancer of ovary': 7.57,
#  'Cancer of pancreas': 8.3,
#  'Cancer of prostate': 7.33,
#  'Cancer of rectum and anus': 8.64,
#  'Cancer of stomach': 8.98,
#  'Cancer of testis': 7.18,
#  'Cancer of thyroid': 4.5,
#  'Cancer of uterus': 6.85,
#  'Cancer; other and unspecified primary': 6.67,
#  'Cancer; other respiratory and intrathoracic': 6.99,
#  'Cardiac and circulatory congenital anomalies': 5.17,
#  'Cardiac arrest and ventricular fibrillation': 6.99,
#  'Cardiac dysrhythmias': 5.73,
#  'Cataract': 4.67,
#  'Chronic kidney disease': 6.52,
#  'Chronic obstructive pulmonary disease and bronchiectasis': 7.01,
#  'Chronic ulcer of skin': 8.59,
#  'Coagulation and hemorrhagic disorders': 5.73,
#  'Coma; stupor; and brain damage': 6.7,
#  'Complication of device; implant or graft': 7.52,
#  'Complications of surgical procedures or medical care': 6.57,
#  'Conditions associated with dizziness or vertigo': 3.65,
#  'Conduction disorders': 4.71,
#  'Congestive heart failure; nonhypertensive': 8.65,
#  'Contraceptive and procreative management': 2.4,
#  'Coronary atherosclerosis and other heart disease': 6.47,
#  'Crushing injury or internal injury': 6.69,
#  'Cystic fibrosis': 9.15,
#  'Deficiency and other anemia': 6.03,
#  'Delirium, dementia, and amnestic and other cognitive disorders': 10.04,
#  'Developmental disorders': 5.84,
#  'Diabetes mellitus with complications': 7.52,
#  'Diabetes mellitus without complication': 3.64,
#  'Diabetes or abnormal glucose tolerance complicating pregnancy; childbirth; or the puerperium': 3.62,
#  'Digestive congenital anomalies': 5.57,
#  'Diseases of mouth; excluding dental': 4.49,
#  'Diseases of white blood cells': 6.4,
#  'Disorders of lipid metabolism': 4.53,
#  'Disorders of teeth and jaw': 3.83,
#  'Disorders usually diagnosed in infancy, childhood, or adolescence': 7.99,
#  'Diverticulosis and diverticulitis': 7.12,
#  'E Codes: Unclassified': 4.53,
#  'Early or threatened labor': 4.8,
#  'Ectopic pregnancy': 2.56,
#  'Encephalitis (except that caused by tuberculosis or sexually transmitted disease)': 9.67,
#  'Endometriosis': 3.3,
#  'Epilepsy; convulsions': 6.04,
#  'Esophageal disorders': 4.93,
#  'Essential hypertension': 3.86,
#  'Female infertility': 2.57,
#  'Fetal distress and abnormal forces of labor': 3.15,
#  'Fetopelvic disproportion; obstruction': 3.09,
#  'Fever of unknown origin': 4.55,
#  'Fluid and electrolyte disorders': 5.86,
#  'Forceps delivery': 2.55,
#  'Fracture of lower limb': 7.6,
#  'Fracture of neck of femur (hip)': 8.64,
#  'Fracture of upper limb': 5.42,
#  'Gangrene': 10.25,
#  'Gastritis and duodenitis': 4.81,
#  'Gastroduodenal ulcer (except hemorrhage)': 6.75,
#  'Gastrointestinal hemorrhage': 6.36,
#  'Genitourinary congenital anomalies': 4.07,
#  'Genitourinary symptoms and ill-defined conditions': 4.88,
#  'Glaucoma': 3.26,
#  'Gout and other crystal arthropathies': 4.98,
#  'HIV infection': 8.75,
#  'Headache; including migraine': 3.71,
#  'Heart valve disorders': 9.21,
#  'Hemorrhage during pregnancy; abruptio placenta; placenta previa': 5.46,
#  'Hemorrhoids': 4.39,
#  'Hepatitis': 6.99,
#  'Hodgkin`s disease': 11.05,
#  'Hyperplasia of prostate': 5.23,
#  'Hypertension complicating pregnancy; childbirth and the puerperium': 5.08,
#  'Hypertension with complications and secondary hypertension': 6.98,
#  'Immunity disorders': 6.98,
#  'Immunizations and screening for infectious disease': 5.6,
#  'Impulse control disorders, NEC': 8.24,
#  'Induced abortion': 2.73,
#  'Infective arthritis and osteomyelitis (except that caused by tuberculosis or sexually transmitted disease)': 8.8,
#  'Inflammation; infection of eye (except that caused by tuberculosis or sexually transmitteddisease)': 4.82,
#  'Inflammatory conditions of male genital organs': 5.59,
#  'Inflammatory diseases of female pelvic organs': 4.7,
#  'Influenza': 6.09,
#  'Intestinal infection': 6.13,
#  'Intestinal obstruction without hernia': 7.99,
#  'Intracranial injury': 7.54,
#  'Joint disorders and dislocations; trauma-related': 3.91,
#  'Late effects of cerebrovascular disease': 11.03,
#  'Leukemias': 12.5,
#  'Lung disease due to external agents': 5.84,
#  'Lymphadenitis': 3.8,
#  'Maintenance chemotherapy; radiotherapy': 8.16,
#  'Malaise and fatigue': 6.53,
#  'Malignant neoplasm without specification of site': 7.43,
#  'Malposition; malpresentation': 3.69,
#  'Medical examination/evaluation': 2.08,
#  'Melanomas of skin': 5.2,
#  'Meningitis (except that caused by tuberculosis or sexually transmitted disease)': 7.05,
#  'Menopausal disorders': 3.57,
#  'Menstrual disorders': 2.89,
#  'Miscellaneous disorders': 6.12,
#  'Mood disorders': 11.69,
#  'Multiple myeloma': 11.59,
#  'Multiple sclerosis': 6.23,
#  'Mycoses': 8.23,
#  'Nausea and vomiting': 4.07,
#  'Neoplasms of unspecified nature or uncertain behavior': 5.93,
#  'Nephritis; nephrosis; renal sclerosis': 6.45,
#  'Nervous system congenital anomalies': 5.36,
#  'Non-Hodgkin`s lymphoma': 10.24,
#  'Noninfectious gastroenteritis': 4.83,
#  'Nonmalignant breast conditions': 3.9,
#  'Nonspecific chest pain': 3.44,
#  'Nutritional deficiencies': 8.15,
#  'OB-related trauma to perineum and vulva': 2.71,
#  'Occlusion or stenosis of precerebral arteries': 4.75,
#  'Open wounds of extremities': 4.62,
#  'Open wounds of head; neck; and trunk': 3.62,
#  'Osteoarthritis': 5.59,
#  'Osteoporosis': 6.11,
#  'Other CNS infection and poliomyelitis': 10.83,
#  'Other acquired deformities': 5.32,
#  'Other aftercare': 10.26,
#  'Other and ill-defined cerebrovascular disease': 5.19,
#  'Other and ill-defined heart disease': 5.09,
#  'Other and unspecified benign neoplasm': 5.4,
#  'Other bone disease and musculoskeletal deformities': 4.42,
#  'Other circulatory disease': 5.25,
#  'Other complications of birth; puerperium affecting management of mother': 4.39,
#  'Other complications of pregnancy': 4.14,
#  'Other congenital anomalies': 4.05,
#  'Other connective tissue disease': 5.63,
#  'Other diseases of bladder and urethra': 5.63,
#  'Other diseases of kidney and ureters': 4.47,
#  'Other diseases of veins and lymphatics': 6.25,
#  'Other disorders of stomach and duodenum': 6.17,
#  'Other ear and sense organ disorders': 3.8,
#  'Other endocrine disorders': 6.38,
#  'Other eye disorders': 3.62,
#  'Other female genital disorders': 4.23,
#  'Other fractures': 6.7,
#  'Other gastrointestinal disorders': 6.42,
#  'Other hematologic conditions': 5.69,
#  'Other hereditary and degenerative nervous system conditions': 6.32,
#  'Other infections; including parasitic': 5.63,
#  'Other inflammatory condition of skin': 6.04,
#  'Other injuries and conditions due to external causes': 4.8,
#  'Other liver diseases': 7.11,
#  'Other lower respiratory disease': 5.29,
#  'Other male genital disorders': 4.72,
#  'Other nervous system disorders': 6.52,
#  'Other non-epithelial cancer of skin': 6.2,
#  'Other non-traumatic joint disorders': 4.26,
#  'Other nutritional; endocrine; and metabolic disorders': 5.99,
#  'Other pregnancy and delivery including normal': 3.1,
#  'Other screening for suspected conditions (not mental disorders or infectious disease)': 3.75,
#  'Other skin disorders': 4.41,
#  'Other upper respiratory disease': 4.27,
#  'Other upper respiratory infections': 3.71,
#  'Otitis media and related conditions': 3.83,
#  'Ovarian cyst': 3.06,
#  'Pancreatic disorders (not diabetes)': 6.85,
#  'Paralysis': 7.69,
#  'Parkinson`s disease': 6.62,
#  'Pathological fracture': 7.89,
#  'Peri-; endo-; and myocarditis; cardiomyopathy (except that caused by tuberculosis or sexually transmitted disease)': 6.79,
#  'Peripheral and visceral atherosclerosis': 6.78,
#  'Peritonitis and intestinal abscess': 7.44,
#  'Personality disorders': 7.73,
#  'Phlebitis; thrombophlebitis and thromboembolism': 6.55,
#  'Pleurisy; pneumothorax; pulmonary collapse': 7.54,
#  'Pneumonia (except that caused by tuberculosis or sexually transmitted disease)': 7.83,
#  'Poisoning by nonmedicinal substances': 4.71,
#  'Poisoning by other medications and drugs': 4.97,
#  'Poisoning by psychotropic agents': 4.71,
#  'Polyhydramnios and other problems of amniotic cavity': 5.46,
#  'Postabortion complications': 3.02,
#  'Previous C-section': 3.59,
#  'Prolapse of female genital organs': 2.84,
#  'Prolonged pregnancy': 3.13,
#  'Pulmonary heart disease': 6.93,
#  'Regional enteritis and ulcerative colitis': 6.79,
#  'Rehabilitation care; fitting of prostheses; and adjustment of devices': 13.43,
#  'Residual codes; unclassified': 5.27,
#  'Respiratory failure; insufficiency; arrest (adult)': 9.89,
#  'Retinal detachments; defects; vascular occlusion; and retinopathy': 3.1,
#  'Rheumatoid arthritis and related disease': 5.41,
#  'Schizophrenia and other psychotic disorders': 14.09,
#  'Screening and history of mental health and substance abuse codes': 6.91,
#  'Secondary malignancies': 7.86,
#  'Septicemia (except in labor)': 10.68,
#  'Sexually transmitted infections (not HIV or hepatitis)': 6.46,
#  'Shock': 8.6,
#  'Sickle cell anemia': 8.11,
#  'Skin and subcutaneous tissue infections': 6.73,
#  'Skull and face fractures': 4.47,
#  'Spinal cord injury': 10.23,
#  'Spondylosis; intervertebral disc disorders; other back problems': 6.1,
#  'Spontaneous abortion': 2.36,
#  'Sprains and strains': 4.14,
#  'Substance-related disorders': 7.56,
#  'Suicide and intentional self-inflicted injury': 4.88,
#  'Superficial injury; contusion': 4.55,
#  'Syncope': 4.43,
#  'Systemic lupus erythematosus and connective tissue disorders': 6.98,
#  'Thyroid disorders': 5.2,
#  'Transient cerebral ischemia': 4.1,
#  'Tuberculosis': 13.74,
#  'Umbilical cord complication': 3.3,
#  'Urinary tract infections': 6.85,
#  'Varicose veins of lower extremity': 5.69,
#  'Viral infection': 5.11}

# %%
# encoding using maping dict_ccs_diagnosis_description
df['ccs_diagnosis_description'] = df['ccs_diagnosis_description'].map(dict_ccs_diagnosis_description)

# %%
# Target Encoding (Mean Encoding) for (ccs_procedure_description: 232 unique values):
dict_ccs_procedure_description=round(df.groupby('ccs_procedure_description')['length_of_stay'].mean(),2).to_dict()
dict_ccs_procedure_description
# Out:
# {'ABDOMINAL PARACENTESIS': 8.12,
#  'ABORTION (TERM OF PREG)': 5.08,
#  'ALCO/DRUG REHAB/DETOX': 8.4,
#  'AMPUTATE LOWER EXTRMITY': 11.46,
#  'AORTIC RESECTION; REPL': 7.86,
#  'APPENDECTOMY': 6.12,
#  'ART RUPT MEMB ASSIS DLV': 2.66,
#  'ARTERIAL BLOOD GASES': 4.65,
#  'ARTERIO FEMORAL/LOW ART': 6.71,
#  'ARTERIO/VENOGRAM-NOT HH': 5.42,
#  'ARTERIOVENOUS FISTULA': 10.61,
#  'ARTHROCENTESIS': 7.08,
#  'ARTHROPLASTY KNEE': 6.29,
#  'ARTHROPLASTY-NOT HIP/KN': 3.76,
#  'ARTHROSCOPY': 4.7,
#  'BIOPSY OF LIVER': 8.39,
#  'BLOOD TRANSFUSION': 7.06,
#  'BONE MARROW BIOPSY': 11.53,
#  'BONE MARROW TRANSPLANT': 18.64,
#  'BREAST BIOPSY & DX PRCS': 8.12,
#  'BUNIONECTOMY/TOE DEFORM': 4.77,
#  'CANCER CHEMOTHERAPY': 9.32,
#  'CARDIAC PACEMAKER/DEFIB': 6.98,
#  'CARDIAC STRESS TESTS': 3.95,
#  'CEREBRAL ARTERIOGRAM': 5.75,
#  'CESAREAN SECTION': 7.11,
#  'CHOLECYSTECTOMY/EXPLOR': 7.31,
#  'CIRCUMCISION': 7.34,
#  'COLONOSCOPY AND BIOPSY': 6.97,
#  'COLORECTAL RESECTION': 10.57,
#  'COLOSTOMY; TEMP/PERM': 11.01,
#  'COMP AXIAL TOMOGR (CT)': 5.07,
#  'CONTRAST AORTOGRAM': 6.44,
#  'CONTROL OF EPISTAXIS': 5.61,
#  'CONV OF CARDIAC RHYTHM': 5.94,
#  'COR ARTERY BYP GRF-CABG': 11.46,
#  'CORNEAL TRANSPLANT': 5.15,
#  'CORONARY THROMBOLYSIS': 5.5,
#  'CT SCAN ABDOMEN': 4.4,
#  'CT SCAN CHEST': 4.7,
#  'D&C; ASPIR AFT DLV/ABOR': 3.02,
#  'DEBRIDE WOUND,INF,BURN': 8.78,
#  'DECOMP PERIPHERAL NERVE': 4.52,
#  'DES LES RETINA/CHOROID': 4.27,
#  'DIAGNOSTIC SPINAL TAP': 7.35,
#  'DIV OF JOINT CAPSULE': 3.59,
#  'DX AMNIOCENTESIS': 3.61,
#  'DX BRONCHOSCOPY & BIOPS': 8.86,
#  'DX CARDIAC CATHETERIZTN': 6.2,
#  'DX DILAT/CURETTAGE -D&C': 4.81,
#  'DX ENDOCRINE PRCS': 7.61,
#  'DX PHYSICAL THERAPY': 9.52,
#  'DX PRCS ON EAR': 7.23,
#  'DX PRCS ON EYE': 6.05,
#  'DX PRCS ON NOSE & MOUTH': 6.43,
#  'DX PRCS; MALE GENITAL': 7.92,
#  'DX ULTRASOUND AB/RETRO': 4.17,
#  'DX ULTRASOUND HEAD/NECK': 4.44,
#  'DX ULTRASOUND HEART': 5.74,
#  'DX ULTRASOUND OF GI': 4.28,
#  'DX ULTRASOUND URINARY': 4.98,
#  'ELECTROCARDIOGRAM': 3.99,
#  'ELECTROENCEPHALOGRAM': 6.07,
#  'ELECTROGR CARDIAC MONIT': 4.17,
#  'EMBOL-/ENDARTER-ECTOMY': 7.58,
#  'ENDARTERECTOMY;VES HEAD': 6.92,
#  'ENDO RETRO CAN OF PANCR': 6.53,
#  'ENDOSCOPY URINARY TRACT': 6.8,
#  'ENTERAL/PARENTERAL NUTR': 9.31,
#  'EPISIOTOMY': 2.93,
#  'ESOPHAGEAL DILATATION': 6.38,
#  'EXC OF SEMI CART KNEE': 5.59,
#  'EXCISION OF SKIN LESION': 6.71,
#  'EXCISION; LYS PERI ADHS': 8.97,
#  'EXPLORATORY LAPAROTOMY': 8.02,
#  'EXTRA CIRC AUX OPEN HRT': 11.74,
#  'EXTRACORP LTIHO;URINARY': 4.94,
#  'FETAL MONITORING': 3.97,
#  'FORCEP;VAC;BREACH DELIV': 2.91,
#  'GASTRECTOMY; PART/TOTAL': 7.83,
#  'GASTROSTOMY; TEMP/PERM': 12.2,
#  'GENI INCONTINENCE PRCS': 1.7,
#  'GLAUCOMA PROCEDURES': 4.84,
#  'HEART VALVE PRCS': 11.21,
#  'HEMODIALYSIS': 6.83,
#  'HEMORRHOID PRCS': 5.89,
#  'HIP REPLACEMENT,TOT/PRT': 7.68,
#  'HYSTERECTOMY; AB/VAG': 5.0,
#  'ILEO- & OT ENTER-OSTOMY': 11.49,
#  'INCIS/DRAIN, SKIN/SUBCU': 6.77,
#  'INCISION & EXCISION CNS': 9.49,
#  'INCISION OF PLEURA': 8.91,
#  'INDWELLING CATHETER': 6.35,
#  'INGUINAL/FEMORAL HERNIA': 6.17,
#  'INJ/ASP MUSC,TENDONS,ST': 7.37,
#  'INJ/LIG ESOPH VARICES': 4.71,
#  'INS CATHETER/SPNL STIM': 5.99,
#  'INTRAOP CHOLANGIOGRAM': 7.05,
#  'INTRAVENOUS PYELOGRAM': 4.49,
#  'IRR XCRANIAL VENT SHUNT': 8.86,
#  'KIDNEY TRANSPLANT': 7.42,
#  'LAMINECTOMY; EXC IV DSC': 6.32,
#  'LAPAROSCOPY': 5.49,
#  'LENS & CATARACT PRCS': 4.86,
#  'LIG/OCCL FALLOPIAN TUBE': 2.66,
#  'LOBECTOMY/PNEUMONECTOMY': 7.18,
#  'LOC EXC LRG INTEST LESN': 9.14,
#  'LOWER GI X-RAY': 5.45,
#  'LUMPECTOMY, QUAD BREAST': 4.44,
#  'MAG RESONANCE IMAGING': 5.32,
#  'MAMMOGRAPHY': 6.44,
#  'MASTECTOMY': 4.0,
#  'MASTOIDECTOMY': 5.68,
#  'MICRO EX (BACT SMEAR)': 6.74,
#  'MYELOGRAM': 6.8,
#  'MYRINGOTOMY': 7.4,
#  'NASOGASTRIC TUBE': 6.58,
#  'NEPHRECTOMY; PART/TOTAL': 5.87,
#  'NEPHRO-/NEPHROS-TOMY': 7.84,
#  'NO PROC': 6.36,
#  'NONOP RMVL FOREIGN BODY': 5.37,
#  'NONOP URINARY SYS MEASR': 5.62,
#  'OOPHORECTOMY; UNI/BILAT': 5.17,
#  'OPEN PROSTATECTOMY': 5.38,
#  'OPHTHALM-/OT-OLOGIC DX': 4.86,
#  'ORAL AND DENTAL SVCS': 6.52,
#  'OT DX CARDIOVASC PRCS': 6.41,
#  'OT DX PRC (INTERVW,EVAL': 5.47,
#  'OT DX PRC SKIN/SUBCUTAN': 7.29,
#  'OT DX PRCS OF RESP TRCT': 7.65,
#  'OT DX PRCS ON LUNG': 7.1,
#  'OT DX PRCS ON MUSC/SKEL': 9.09,
#  'OT DX PRCS URINARY TRCT': 7.99,
#  'OT DX PRCS; FEMALE ORGN': 5.52,
#  'OT DX RADIO & RELATED': 4.8,
#  'OT EXC CERVIX & UTERUS': 3.88,
#  'OT EXTRAOCULAR MUSC/ORB': 5.11,
#  'OT FRACTURE/DISLOC PRC': 6.39,
#  'OT INTRAOCULAR THER PRC': 4.93,
#  'OT NON-OR GI THER PRCS': 7.41,
#  'OT NON-OR LW GI THER PR': 6.37,
#  'OT NON-OR THER CARDIO': 8.91,
#  'OT NON-OR THER NERV SYS': 6.58,
#  'OT NON-OR THER PRC MUSC': 6.7,
#  'OT NON-OR THER PRC NOSE': 3.82,
#  'OT NON-OR THER PRC RESP': 8.57,
#  'OT NON-OR THER PRC SKIN': 7.95,
#  'OT NON-OR THER PRC URIN': 6.55,
#  'OT NON-OR THER PRC; FEM': 3.09,
#  'OT NON-OR THER PRCS; M': 6.68,
#  'OT NON-OR UP GI THER PR': 7.21,
#  'OT OPER FALLOPIAN TUBES': 3.33,
#  'OT OPERATIONS ON OVARY': 3.37,
#  'OT OR GI THER PRCS': 8.36,
#  'OT OR LOW GI THER PRCS': 8.13,
#  'OT OR PRCS ON VES HEAD': 8.26,
#  'OT OR PRCS VES NOT HEAD': 8.47,
#  'OT OR RX PRCS RESP SYS': 8.92,
#  'OT OR THER PRC MUSC/SKL': 6.75,
#  'OT OR THER PRC ON JOINT': 6.72,
#  'OT OR THER PRC SKN/BRST': 6.49,
#  'OT OR THER PRC; FEM ORG': 3.94,
#  'OT OR THER PRCS ON BONE': 6.73,
#  'OT OR THER PRCS URINARY': 7.52,
#  'OT OR THER PRCS; MALE': 5.44,
#  'OT OR UP GI THER PRCS': 8.14,
#  'OT ORGAN TRANSPLANTATN': 15.89,
#  'OT PHYS THER/REHAB': 10.67,
#  'OT PRCS TO ASSIST DELIV': 4.07,
#  'OT THER ENDOCRINE PRCS': 5.53,
#  'OT THER OBSTETRICAL PRC': 2.78,
#  'OT THER PRCS EYELIDS': 4.08,
#  'OT THER PRCS ON MUSCLES': 7.05,
#  'OT THER PRCS; HEM/LYMPH': 7.24,
#  'OT THERAPEUTIC EAR PRCS': 4.62,
#  'OT VASC CATH; NOT HEART': 9.0,
#  'OT VASCULAR BYP/SHUNT': 8.55,
#  'OTHER BOWEL DX PRCS': 6.4,
#  'OTHER CT SCAN': 4.32,
#  'OTHER DX NERV SYS PRCS': 9.03,
#  'OTHER DX ULTRASOUND': 5.19,
#  'OTHER GI DX PRCS': 7.32,
#  'OTHER HERNIA REPAIR': 6.91,
#  'OTHER OR HEART PRCS': 8.55,
#  'OTHER OR THER NERV SYS': 7.54,
#  'OTHER OR THER PRCS NOSE': 5.38,
#  'OTHER RADIOISOTOPE SCAN': 4.84,
#  'OTHER RESP THERAPY': 6.29,
#  'OTHER THERAPEUTIC PRCS': 6.09,
#  'PARTIAL EXCISION BONE': 8.61,
#  'PERC TRANSLUM COR ANGIO': 6.3,
#  'PERIPH VASCULAR BYPASS': 9.99,
#  'PERITONEAL DIALYSIS': 5.97,
#  'PHYS THER EXER, MANIPUL': 10.22,
#  'PLASTIC PRCS ON NOSE': 3.17,
#  'PRCS ON SPLEEN': 7.87,
#  'PRCS ON THE URETHRA': 5.11,
#  'PROCTOSCOPY & AR BIOPSY': 6.76,
#  'PROPHYLACTIC VAC/INOCUL': 4.83,
#  'PSYCHO/PSYCHI EVAL/THER': 12.43,
#  'RADIOISOTOPE BONE SCAN': 7.07,
#  'RADIOISOTOPE PULM SCAN': 4.11,
#  'RADIOISOTOPE SCAN/FUNCT': 4.31,
#  'REPAIR CUR OBS LACERATN': 3.25,
#  'REPAIR CYST-/RECT-OCELE': 2.88,
#  'REPAIR RETINAL TEAR': 3.31,
#  'RESP INTUB/MECH VENTIL': 9.41,
#  'RMVL ECTOPIC PREGNANCY': 2.8,
#  'ROUTINE CHEST X-RAY': 4.13,
#  'SKIN GRAFT': 9.08,
#  'SMALL BOWEL RESECTON': 10.51,
#  'SPINAL FUSION': 7.98,
#  'SUTURE SKIN/SUBCUT TISS': 4.51,
#  'SWAN-GANZ CATH MONITOR': 8.38,
#  'THERAPEUTIC RADIOLOGY': 9.52,
#  'THYROIDECTOMY;PART/FULL': 4.05,
#  'TONSIL-/ADENOID-ECTOMY': 3.67,
#  'TRACHE-/LARYNG-OSCOPY': 5.89,
#  'TRACHEOSTOMY; TEMP/PERM': 18.1,
#  'TRACTN, SPLNT, OT WOUND': 5.64,
#  'TRANS RES PROSTATE-TURP': 6.62,
#  'TRANSURETHRAL EXCISION': 6.16,
#  'TRTMNT,FACE FRACT/DISLC': 5.1,
#  'TRTMNT,FRAC HIP/FEMUR': 8.37,
#  'TRTMNT,FRAC LOWR EXTREM': 7.6,
#  'TRTMNT,FRAC RADIUS/ULNA': 5.56,
#  'TYMPANOPLASTY': 1.5,
#  'UNGROUPABLE': 5.36,
#  'UP GASTRO ENDOSC/BIOPSY': 6.9,
#  'UPPER GI X-RAY': 6.36,
#  'URETERAL CATHETERIZATN': 5.78,
#  'VARI VEIN STRIP;LOW LMB': 4.35}

# %%
# encoding using maping dict_ccs_diagnosis_description
df['ccs_procedure_description'] = df['ccs_procedure_description'].map(dict_ccs_procedure_description)

# %%
# Target Encoding (Mean Encoding) for (apr_drg_description:  285 unique values):
dict_apr_drg_description=round(df.groupby('apr_drg_description')['length_of_stay'].mean(),2).to_dict()
dict_apr_drg_description
# Out:
# {'Abdominal pain': 4.26,
#  'Abortion w/o D&C, aspiration curettage or hysterotomy': 1.88,
#  'Acute & subacute endocarditis': 9.34,
#  'Acute anxiety & delirium states': 5.36,
#  'Acute leukemia': 12.47,
#  'Acute major eye infections': 5.33,
#  'Acute myocardial infarction': 6.1,
#  'Adjustment disorders & neuroses except depressive diagnoses': 6.71,
#  'Alcohol & drug dependence w rehab or rehab/detox therapy': 13.5,
#  'Alcohol abuse & dependence': 7.3,
#  'Alcoholic liver disease': 7.11,
#  'Allergic reactions': 3.52,
#  'Amputation of lower limb except toes': 11.68,
#  'Anal procedures': 5.19,
#  'Angina pectoris & coronary atherosclerosis': 3.8,
#  'Appendectomy': 5.89,
#  'Asthma': 4.89,
#  'BPD & oth chronic respiratory diseases arising in perinatal period': 5.25,
#  'Bacterial & tuberculous infections of nervous system': 9.58,
#  'Behavioral disorders': 8.01,
#  'Bipolar disorders': 12.58,
#  'Bone marrow transplant': 18.67,
#  'Brain contusion/laceration & complicated skull Fx, coma < 1 hr or no coma': 5.61,
#  'Breast procedures except mastectomy': 3.72,
#  'Bronchiolitis & RSV pneumonia': 5.21,
#  'Burns with skin graft except extensive 3rd degree burns': 11.24,
#  'CHEMOTHERAPY': 7.93,
#  'CVA & precerebral occlusion w infarct': 7.96,
#  'Cardiac arrest and shock': 4.74,
#  'Cardiac arrhythmia & conduction disorders': 5.3,
#  'Cardiac catheterization for coronary artery disease': 6.69,
#  'Cardiac catheterization for other non-coronary conditions': 4.39,
#  'Cardiac defibrillator & heart assist implant': 8.91,
#  'Cardiac pacemaker & defibrillator device replacement': 5.07,
#  'Cardiac pacemaker & defibrillator revision except device replacement': 6.02,
#  'Cardiac structural & valvular disorders': 5.36,
#  'Cardiac valve procedures w AMI or complex PDX': 12.52,
#  'Cardiac valve procedures w/o AMI or complex PDX': 10.37,
#  'Cardiomyopathy': 4.26,
#  'Cellulitis & other skin infections': 6.55,
#  'Cervical spinal fusion & other back/neck proc exc disc excis/decomp': 6.59,
#  'Cesarean delivery': 6.73,
#  'Chest pain': 3.18,
#  'Cholecystectomy except laparoscopic': 7.73,
#  'Chronic obstructive pulmonary disease': 6.57,
#  'Cleft lip & palate repair': 2.26,
#  'Coagulation & platelet disorders': 5.68,
#  'Cocaine abuse & dependence': 6.73,
#  'Concussion, closed skull Fx nos,uncomplicated intracranial injury, coma < 1 hr or no coma': 3.29,
#  'Connective tissue disorders': 6.38,
#  'Contusion, open wound & other trauma to skin & subcutaneous tissue': 3.98,
#  'Coronary bypass w AMI or complex PDX': 11.44,
#  'Coronary bypass w/o AMI or complex PDX': 10.26,
#  'Craniotomy except for trauma': 9.04,
#  'Craniotomy for multiple significant trauma': 10.63,
#  'Craniotomy for trauma': 9.57,
#  'Cystic fibrosis - pulmonary disease': 8.41,
#  'D&C, aspiration curettage or hysterotomy for obstetric diagnoses': 2.71,
#  'Degenerative nervous system disorders exc mult sclerosis': 8.32,
#  'Dental & oral diseases & injuries': 4.18,
#  'Depression except major depressive disorder': 8.31,
#  'Diabetes': 5.89,
#  'Digestive malignancy': 7.7,
#  'Dilation & curettage for non-obstetric diagnoses': 4.1,
#  'Disorders of gallbladder & biliary tract': 5.5,
#  'Disorders of pancreas except malignancy': 6.3,
#  'Disorders of personality & impulse control': 7.77,
#  'Diverticulitis & diverticulosis': 5.87,
#  'Dorsal & lumbar fusion proc except for curvature of back': 7.65,
#  'Dorsal & lumbar fusion proc for curvature of back': 7.42,
#  'Drug & alcohol abuse or dependence, left against medical advice': 5.67,
#  'Ear, nose, mouth, throat, cranial/facial malignancies': 8.9,
#  'Eating disorders': 10.83,
#  'Ectopic pregnancy procedure': 2.42,
#  'Electrolyte disorders except hypovolemia related': 5.88,
#  'Extensive 3rd degree burns w skin graft': 18.03,
#  'Extensive 3rd degree or full thickness burns w/o skin graft': 6.69,
#  'Extensive abdominal/thoracic procedures for mult significant trauma': 11.62,
#  'Extensive procedure unrelated to principal diagnosis': 9.96,
#  'Extracranial vascular procedures': 6.84,
#  'Eye disorders except major infections': 3.41,
#  'Eye procedures except orbit': 3.9,
#  'Facial bone procedures except major cranial/facial bone procedures': 4.34,
#  'False labor': 2.59,
#  'Female reproductive system infections': 4.97,
#  'Female reproductive system malignancy': 7.72,
#  'Female reproductive system reconstructive procedures': 2.75,
#  'Fever': 4.29,
#  'Foot & toe procedures': 8.26,
#  'Fracture of femur': 6.01,
#  'Fracture of pelvis or dislocation of hip': 5.77,
#  'Fractures & dislocations except femur, pelvis & back': 5.14,
#  'Gastrointestinal vascular insufficiency': 5.46,
#  'HIV w major HIV related condition': 6.81,
#  'HIV w multiple major HIV related conditions': 10.55,
#  'HIV w multiple significant HIV related conditions': 6.03,
#  'HIV w one signif HIV cond or w/o signif related cond': 4.24,
#  'Hand & wrist procedures': 4.57,
#  'Head trauma w coma >1 hr or hemorrhage': 6.34,
#  'Heart &/or lung transplant': 17.89,
#  'Heart failure': 7.75,
#  'Hepatic coma & other major acute liver disorders': 7.45,
#  'Hernia procedures except inguinal, femoral & umbilical': 6.64,
#  'Hip and femur fracture repair': 8.65,
#  'Hip joint replacement': 7.49,
#  'Hypertension': 3.78,
#  'Hypovolemia & related electrolyte disorders': 5.58,
#  'Inborn errors of metabolism': 4.91,
#  'Infections of upper respiratory tract': 4.12,
#  'Infectious & parasitic diseases including HIV w O.R. procedure': 12.65,
#  'Inflammatory bowel disease': 5.94,
#  'Inguinal, femoral & umbilical hernia procedures': 5.41,
#  'Interstitial & alveolar lung diseases': 6.88,
#  'Intervertebral disc excision & decompression': 6.34,
#  'Intestinal obstruction': 6.28,
#  'Intracranial hemorrhage': 7.49,
#  'Kidney & urinary tract infections': 6.66,
#  'Kidney & urinary tract malignancy': 6.88,
#  'Kidney & urinary tract procedures for malignancy': 6.85,
#  'Kidney & urinary tract procedures for nonmalignancy': 5.92,
#  'Kidney transplant': 7.26,
#  'Knee & lower leg procedures except foot': 7.08,
#  'Knee joint replacement': 6.55,
#  'Laparoscopic cholecystectomy': 6.62,
#  'Liver transplant &/or intestinal transplant': 15.02,
#  'Lymphatic & other malignancies & neoplasms of uncertain behavior': 7.02,
#  'Lymphoma, myeloma & non-acute leukemia': 8.97,
#  'Major O.R. procedures for lymphatic/hematopoietic/other neoplasms': 8.74,
#  'Major abdominal vascular procedures': 8.59,
#  'Major biliary tract procedures': 8.41,
#  'Major bladder procedures': 8.96,
#  'Major cardiothoracic repair of heart anomaly': 8.59,
#  'Major chest & respiratory trauma': 5.19,
#  'Major cranial/facial bone procedures': 7.3,
#  'Major depressive disorders & other/unspecified psychoses': 11.93,
#  'Major esophageal disorders': 5.57,
#  'Major gastrointestinal & peritoneal infections': 7.16,
#  'Major hematologic/immunologic diag exc sickle cell crisis & coagul': 7.08,
#  'Major larynx & trachea procedures': 11.78,
#  'Major male pelvic procedures': 5.42,
#  'Major pancreas, liver & shunt procedures': 8.81,
#  'Major respiratory & chest procedures': 8.9,
#  'Major respiratory infections & inflammations': 8.68,
#  'Major skin disorders': 6.02,
#  'Major small & large bowel procedures': 9.85,
#  'Major stomach, esophageal & duodenal procedures': 9.05,
#  'Male reproductive system diagnoses except malignancy': 4.96,
#  'Malfunction, reaction & complication of GI device or procedure': 6.27,
#  'Malfunction, reaction, complic of genitourinary device or proc': 7.3,
#  'Malfunction, reaction, complic of orthopedic device or procedure': 6.46,
#  'Malfunction,reaction,complication of cardiac/vasc device or procedure': 6.28,
#  'Malignancy of hepatobiliary system & pancreas': 7.1,
#  'Malignancy, male reproductive system': 9.02,
#  'Malignant breast disorders': 8.06,
#  'Malnutrition, failure to thrive & other nutritional disorders': 7.4,
#  'Mastectomy procedures': 3.57,
#  'Menstrual & other female reproductive system disorders': 3.04,
#  'Mental illness diagnosis w O.R. procedure': 12.58,
#  'Migraine & other headaches': 3.59,
#  'Moderately extensive procedure unrelated to principal diagnosis': 9.13,
#  'Multiple sclerosis & other demyelinating diseases': 6.5,
#  'Multiple significant trauma w/o O.R. procedure': 6.52,
#  'Musculoskeletal & other procedures for multiple significant trauma': 10.7,
#  'Musculoskeletal malignancy & pathol fracture d/t muscskel malig': 8.73,
#  'Nephritis & nephrosis': 6.42,
#  'Nervous system malignancy': 7.86,
#  'Non-bacterial infections of nervous system exc viral meningitis': 8.11,
#  'Nonextensive procedure unrelated to principal diagnosis': 7.79,
#  'Nonspecific CVA & precerebral occlusion w/o infarct': 4.07,
#  'Nontraumatic stupor & coma': 6.85,
#  'O.R. procedure for other complications of treatment': 6.69,
#  'OTHER VASCULAR PROCEDURES': 8.31,
#  'Opioid abuse & dependence': 6.6,
#  'Orbital procedures': 4.33,
#  'Organic mental health disturbances': 10.24,
#  'Osteomyelitis, septic arthritis & other musculoskeletal infections': 7.97,
#  'Other & unspecified gastrointestinal hemorrhage': 6.1,
#  'Other O.R. proc for obstetric diagnoses except delivery diagnoses': 3.66,
#  'Other O.R. procedures for lymphatic/hematopoietic/other neoplasms': 8.64,
#  'Other aftercare & convalescence': 10.44,
#  'Other anemia & disorders of blood & blood-forming organs': 5.08,
#  'Other antepartum diagnoses': 4.78,
#  'Other back & neck disorders, fractures & injuries': 5.91,
#  'Other bladder procedures': 5.73,
#  'Other cardiothoracic & thoracic vascular procedures': 8.5,
#  'Other circulatory system diagnoses': 4.71,
#  'Other circulatory system procedures': 9.59,
#  'Other complications of treatment': 4.95,
#  'Other digestive system & abdominal procedures': 7.41,
#  'Other digestive system diagnoses': 4.92,
#  'Other disorders of nervous system': 7.19,
#  'Other disorders of the liver': 5.71,
#  'Other drug abuse & dependence': 7.48,
#  'Other ear, nose, mouth & throat procedures': 4.46,
#  'Other ear, nose, mouth,throat & cranial/facial diagnoses': 3.85,
#  'Other endocrine disorders': 5.93,
#  'Other esophageal disorders': 4.45,
#  'Other female reproductive system & related procedures': 4.23,
#  'Other gastroenteritis, nausa & vomiting': 4.45,
#  'Other hepatobiliary, pancreas & abdominal procedures': 8.07,
#  'Other infectious & parasitic diseases': 6.26,
#  'Other injury, poisoning & toxic effect diagnoses': 5.52,
#  'Other kidney & urinary tract diagnoses, signs & symptoms': 4.98,
#  'Other kidney, urinary tract & related procedures': 8.61,
#  'Other major head & neck procedures': 6.17,
#  'Other male reproductive system & related procedures': 5.6,
#  'Other mental health disorders': 8.45,
#  'Other musculoskeletal system & connective tissue diagnoses': 5.19,
#  'Other musculoskeletal system & connective tissue procedures': 6.24,
#  'Other nervous system & related procedures': 6.5,
#  'Other pneumonia': 7.09,
#  'Other procedures for endocrine, nutritional & metabolic disorders': 9.78,
#  'Other procedures of blood & blood-forming organs': 5.58,
#  'Other respiratory & chest procedures': 7.36,
#  'Other respiratory diagnoses except signs, symptoms & minor diagnoses': 5.36,
#  'Other significant hip and femur surgery': 6.84,
#  'Other skin, subcutaneous tissue & breast disorders': 4.42,
#  'Other skin, subcutaneous tissue & related procedures': 6.23,
#  'Other small & large bowel procedures': 7.27,
#  'Other stomach, esophageal & duodenal procedures': 6.43,
#  'Pancreas transplant': 11.55,
#  'Partial thickness burns without skin graft': 5.83,
#  'Pelvic evisceration, radical hysterectomy & other radical GYN procs': 5.08,
#  'Penis procedures': 4.17,
#  'Peptic ulcer & gastritis': 5.21,
#  'Percutaneous coronary intervention w AMI': 6.3,
#  'Percutaneous coronary intervention w/o AMI': 6.02,
#  'Peripheral & other vascular disorders': 5.91,
#  'Peripheral, cranial & autonomic nerve disorders': 5.29,
#  'Peritoneal adhesiolysis': 8.67,
#  'Perm cardiac pacemaker implant w/o AMI, heart failure or shock': 6.4,
#  'Permanent cardiac pacemaker implant w AMI, heart failure or shock': 9.07,
#  'Pituitary & adrenal procedures': 5.45,
#  'Poisoning of medicinal agents': 4.78,
#  'Post-op, post-trauma, other device infections w O.R. procedure': 9.1,
#  'Post-operative, post-traumatic, other device infections': 7.36,
#  'Postpartum & post abortion diagnoses w/o procedure': 3.61,
#  'Preterm labor': 4.46,
#  'Procedure w diag of rehab, aftercare or oth contact w health service': 6.51,
#  'Procedures for obesity': 3.77,
#  'Pulmonary embolism': 6.39,
#  'RENAL FAILURE': 7.92,
#  'Radiotherapy': 8.57,
#  'Rehabilitation': 13.19,
#  'Renal dialysis access device procedure only': 9.86,
#  'Respiratory Failure': 7.59,
#  'Respiratory malignancy': 7.82,
#  'Respiratory signs, symptoms & minor diagnoses': 3.87,
#  'Respiratory system diagnosis w ventilator support 96+ hours': 14.13,
#  'Schizophrenia': 15.1,
#  'Seizure': 5.74,
#  'Septicemia & disseminated infections': 9.57,
#  'Shoulder, upper arm & forearm procedures except joint replacement': 4.97,
#  'Sickle cell anemia crisis': 8.23,
#  'Signs, symptoms & other factors influencing health status': 5.64,
#  'Sinus & mastoid procedures': 3.85,
#  'Skin graft for skin & subcutaneous tissue diagnoses': 6.99,
#  'Skin graft, except hand, for musculoskeletal & connective tissue diagnoses': 9.31,
#  'Skin ulcers': 7.12,
#  'Spinal disorders & injuries': 8.25,
#  'Spinal procedures': 7.06,
#  'Splenectomy': 6.79,
#  'Syncope & collapse': 4.46,
#  'Tendon, muscle & other soft tissue procedures': 6.68,
#  'Testes & scrotal procedures': 5.49,
#  'Thyroid, parathyroid & thyroglossal procedures': 4.04,
#  'Tonsil & adenoid procedures': 3.62,
#  'Toxic effects of non-medicinal substances': 4.32,
#  'Tracheostomy w MV 96+ hours w extensive procedure or ECMO': 18.74,
#  'Tracheostomy w MV 96+ hours w/o extensive procedure': 19.22,
#  'Transient ischemia': 4.04,
#  'Transurethral prostatectomy': 5.67,
#  'Urethral & transurethral procedures': 5.38,
#  'Urinary stones & acquired upper urinary tract obstruction': 3.52,
#  'Uterine & adnexa procedures for leiomyoma': 4.95,
#  'Uterine & adnexa procedures for non-malignancy except leiomyoma': 3.55,
#  'Uterine & adnexa procedures for non-ovarian & non-adnexal malig': 5.85,
#  'Uterine & adnexa procedures for ovarian & adnexal malignancy': 6.7,
#  'Vaginal delivery': 3.31,
#  'Vaginal delivery w complicating procedures exc sterilization &/or D&C': 2.75,
#  'Vaginal delivery w sterilization &/or D&C': 2.96,
#  'Ventricular shunt procedures': 7.44,
#  'Vertigo & other labyrinth disorders': 3.62,
#  'Viral illness': 4.85,
#  'Viral meningitis': 5.55}

# %%
# encoding using maping dict_ccs_diagnosis_description
df['apr_drg_description'] = df['apr_drg_description'].map(dict_apr_drg_description)

# %%
# Target Encoding (Mean Encoding) for ( apr_mdc_description: 24 unique values):
dict_apr_mdc_description = round(df.groupby('apr_mdc_description')['length_of_stay'].mean(),2).to_dict()
dict_apr_mdc_description
# Out:
# {'Alcohol/Drug Use and Alcohol/Drug Induced Organic Mental Disorders': 7.97,
#  'Burns': 8.23,
#  'Diseases and Disorders of Blood, Blood Forming Organs and Immunological Disorders': 6.39,
#  'Diseases and Disorders of the Circulatory System': 6.8,
#  'Diseases and Disorders of the Digestive System': 6.59,
#  'Diseases and Disorders of the Eye': 3.93,
#  'Diseases and Disorders of the Female Reproductive System': 4.85,
#  'Diseases and Disorders of the Hepatobiliary System and Pancreas': 7.01,
#  'Diseases and Disorders of the Kidney and Urinary Tract': 6.91,
#  'Diseases and Disorders of the Male Reproductive System': 5.77,
#  'Diseases and Disorders of the Musculoskeletal System and Conn Tissue': 6.84,
#  'Diseases and Disorders of the Nervous System': 7.21,
#  'Diseases and Disorders of the Respiratory System': 7.36,
#  'Diseases and Disorders of the Skin, Subcutaneous Tissue and Breast': 6.06,
#  'Ear, Nose, Mouth, Throat and Craniofacial Diseases and Disorders': 4.79,
#  'Endocrine, Nutritional and Metabolic Diseases and Disorders': 6.02,
#  'Human Immunodeficiency Virus Infections': 7.63,
#  'Infectious and Parasitic Diseases, Systemic or Unspecified Sites': 9.68,
#  'Lymphatic, Hematopoietic, Other Malignancies, Chemotherapy and Radiotherapy': 9.63,
#  'Mental Diseases and Disorders': 11.66,
#  'Multiple Significant Trauma': 9.19,
#  'Poisonings, Toxic Effects, Other Injuries and Other Complications of Treatment': 5.19,
#  'Pregnancy, Childbirth and the Puerperium': 4.23,
#  'Rehabilitation, Aftercare, Other Factors Influencing Health Status and Other Health Service Contacts': 10.02}

# %%
# encoding using maping dict_apr_mdc_description
df['apr_mdc_description'] =df['apr_mdc_description'].map(dict_apr_mdc_description)

# %%
# Target Encoding (Mean Encoding) for ( type_of_admission: 6 unique values)
dict_type_of_admission = round(df.groupby('type_of_admission')['length_of_stay'].mean(),2).to_dict()
dict_type_of_admission
# Out:
# {'Elective': 6.79,
#  'Emergency': 7.29,
#  'Newborn': 4.76,
#  'Not Available': 5.2,
#  'Trauma': 5.99,
#  'Urgent': 7.21}

# %%
# encoding using maping dict_type_of_admission
df['type_of_admission'] =df['type_of_admission'].map(dict_type_of_admission)

# %%
df.head()
# Out:
#    age_group gender  length_of_stay  type_of_admission  \
# 0          3      F               5               7.29
# 1          1      F               8               7.29
# 2          2      M               8               7.29
# 3          3      F               4               7.29
# 4          3      M               3               7.29
#
#    ccs_diagnosis_description  ccs_procedure_description  apr_drg_description  \
# 0                      11.69                       6.36                12.58
# 1                      11.69                       6.36                12.58
# 2                      11.69                       6.36                12.58
# 3                       5.87                       6.36                 4.89
# 4                       6.04                       6.36                 5.74
#
#    apr_mdc_description  apr_severity_of_illness_description  \
# 0                11.66                                    1
# 1                11.66                                    2
# 2                11.66                                    1
# 3                 7.36                                    1
# 4                 7.21                                    2
#
#    apr_risk_of_mortality apr_medical_surgical_description  \
# 0                      1                          Medical
# 1                      1                          Medical
# 2                      1                          Medical
# 3                      1                          Medical
# 4                      2                          Medical
#
#   emergency_department_indicator
# 0                              Y
# 1                              Y
# 2                              Y
# 3                              Y
# 4                              Y

# %% [markdown]
# #### * Second low cardinality categorical Features:
# * For features with low cardinality we are going to use get dumies to encode it features like:
#
#   - (gender: 2 unique, apr_medical_surgical_description: 2, emergency_department_indicator: 2)

# %%
# Making list for low cardinality features to help in preparing dict after encoded it.
gender_list = df.gender.unique().tolist()
apr_medical_surgical_description_list = df.apr_medical_surgical_description.unique().tolist()
emergency_department_indicator_list = df.emergency_department_indicator.unique().tolist()

# %%
df.head()
# Out:
#    age_group gender  length_of_stay  type_of_admission  \
# 0          3      F               5               7.29
# 1          1      F               8               7.29
# 2          2      M               8               7.29
# 3          3      F               4               7.29
# 4          3      M               3               7.29
#
#    ccs_diagnosis_description  ccs_procedure_description  apr_drg_description  \
# 0                      11.69                       6.36                12.58
# 1                      11.69                       6.36                12.58
# 2                      11.69                       6.36                12.58
# 3                       5.87                       6.36                 4.89
# 4                       6.04                       6.36                 5.74
#
#    apr_mdc_description  apr_severity_of_illness_description  \
# 0                11.66                                    1
# 1                11.66                                    2
# 2                11.66                                    1
# 3                 7.36                                    1
# 4                 7.21                                    2
#
#    apr_risk_of_mortality apr_medical_surgical_description  \
# 0                      1                          Medical
# 1                      1                          Medical
# 2                      1                          Medical
# 3                      1                          Medical
# 4                      2                          Medical
#
#   emergency_department_indicator
# 0                              Y
# 1                              Y
# 2                              Y
# 3                              Y
# 4                              Y

# %%
df = pd.get_dummies(df,drop_first=True)

# %%
df.head()
# Out:
#    age_group  length_of_stay  type_of_admission  ccs_diagnosis_description  \
# 0          3               5               7.29                      11.69
# 1          1               8               7.29                      11.69
# 2          2               8               7.29                      11.69
# 3          3               4               7.29                       5.87
# 4          3               3               7.29                       6.04
#
#    ccs_procedure_description  apr_drg_description  apr_mdc_description  \
# 0                       6.36                12.58                11.66
# 1                       6.36                12.58                11.66
# 2                       6.36                12.58                11.66
# 3                       6.36                 4.89                 7.36
# 4                       6.36                 5.74                 7.21
#
#    apr_severity_of_illness_description  apr_risk_of_mortality  gender_M  \
# 0                                    1                      1         0
# 1                                    2                      1         0
# 2                                    1                      1         1
# 3                                    1                      1         0
# 4                                    2                      2         1
#
#    apr_medical_surgical_description_Surgical  emergency_department_indicator_Y
# 0                                          0                                 1
# 1                                          0                                 1
# 2                                          0                                 1
# 3                                          0                                 1
# 4                                          0                                 1

# %%
dict_gender_M = {'F':0,'M':1}
dict_apr_medical_surgical_description_Surgical = {'Medical':0, 'Surgical':1}
dict_emergency_department_indicator_Y = {'Y':1, 'N':0}

# %% [markdown]
# ### 5. Correlation heatmap:
#      - After encoding to chech if there are tow features highly correlated to each other & drop one of them.

# %%
# I am interested in take a look at correlation matrics after features encoded:
corr_mat = round(df.corr()['length_of_stay'].sort_values(ascending=False),2)
corr_mat
# Out:
# length_of_stay                               1.00
# apr_drg_description                          0.46
# apr_severity_of_illness_description          0.41
# ccs_diagnosis_description                    0.37
# ccs_procedure_description                    0.35
# apr_risk_of_mortality                        0.35
# apr_mdc_description                          0.27
# apr_medical_surgical_description_Surgical    0.11
# age_group                                    0.11
# type_of_admission                            0.04
# gender_M                                     0.04
# emergency_department_indicator_Y             0.03
# Name: length_of_stay, dtype: float64

# %%
# Compute correlation matrix and visualize the correlation heatmap
correlation_matrix = df.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.1f')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# #### From the above correlation heat map if there is high correlation between two features we are going to drop the feature with lower correlation with the target length of stay.
#
# * type_of_admission & emergency_department_indicator_Y have corr = 0.5 we will drop emergency_department_indicator_Y
# * apr_drg_description, ccs_diagnosis_description & apr_mdc_description have corr = 0.7 we will drop ccs_diagnosis_description , apr_mdc_description.
# * apr_drg_description & ccs_procedure_description have corr = 0.5  we will drop ccs_procedure_description
# * apr_severity_of_illness_description & apr_risk_of_mortality have corr = 0.7 we will drop apr_risk_of_mortality

# %%
# dropping highly correlated feature ['emergency_department_indicator_Y','ccs_diagnosis_description','apr_mdc_description','ccs_procedure_description','apr_risk_of_mortality']
df.drop(['emergency_department_indicator_Y','ccs_diagnosis_description','apr_mdc_description','ccs_procedure_description','apr_risk_of_mortality'],axis=1,inplace=True)

# %%
#checking for duplication in data after droping correlated features. 
df.duplicated().sum()
# Out:
# 580931

# %%
# Drop duplicates and reset the index
df = df.drop_duplicates().reset_index(drop=True)

# %%
# Compute correlation matrix and visualize the correlation heatmap
correlation_matrix = df.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.1f')
plt.title('Correlation Heatmap')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143500 entries, 0 to 143499
# Data columns (total 7 columns):
#  #   Column                                     Non-Null Count   Dtype
# ---  ------                                     --------------   -----
#  0   age_group                                  143500 non-null  int64
#  1   length_of_stay                             143500 non-null  int64
#  2   type_of_admission                          143500 non-null  float64
#  3   apr_drg_description                        143500 non-null  float64
#  4   apr_severity_of_illness_description        143500 non-null  int64
#  5   gender_M                                   143500 non-null  uint8
#  6   apr_medical_surgical_description_Surgical  143500 non-null  uint8
# dtypes: float64(2), int64(3), uint8(2)
# memory usage: 5.7 MB

# %%
# saving data frame in csv file in processed folder for the modeling step.
df.to_csv('../data/processed/processed_data.csv',index=False)

# %% [markdown]
# ## **Preprocessing Outcomes Summary:**
#
# The main objective of preprocessing and outcomes as follows:
#
# ### 1. Checking the dataset for irrelevant columns that do not serve our prediction model of length of stay and dealing with them.
#     - Not all the features serve our aim, as we attempt to create a general model that can predict patient length of stay regardless of the city or state. Additionally, 'total_cost' and 'charges' exceeding 120 days of stay do not make sense to keep. The following columns were removed: ['health_service_area','hospital_county','operating_certificate_number','facility_id','facility_name','race','ethnicity', 'zip_code__3_digits','patient_disposition','ccs_diagnosis_code','ccs_procedure_code','apr_drg_code','apr_mdc_code', 'apr_severity_of_illness_code','payment_typology_1','birth_weight','total_charges','total_costs','over_120_stay'].
#
#     - after droping the above irrelevant features 1264916 duplicates appears in the data we drop them.
# ---
# ### 2. Selecting & dropping not Adult patients as their treatment may vary alot from adult.
#      - we drop 342237 instants of 0 to 17 patients and we drop all of them to maintain the data for adult patients.
# ---
# ### 3. handling outliers.
# * There was outliers above 20 days we deal with them by change there values to the end of the wisker which is almost 20 days by this way we are going to keep those patient data and point that prediction of 20 days it means 20 days and above.
# ---
# ### 4. Handling Categorical Variables:
#     1) For ordinal categorical features:
#             - By creating dictionary with ordinal number and maping the dictionary with the ordinal categorical feature.
#
#      2) Encoding nominal feature:
#
#             * For Features with high cardinality we use Target Encoding (Mean Encoding) for nominal categorical features then dropping it features like:
#                   - (ccs_diagnosis_description: 257 unique values, ccs_procedure_description: 232, apr_drg_description: 285, apr_mdc_description: 24,  type_of_admission: 6 unique values)
#
#
#             * For features with low cardinality we use pandas get dumies to encode it features like:
#
#                    - (gender: 2 unique, apr_medical_surgical_description: 2, emergency_department_indicator: 2)
# ---
# ### 5. Correlation heatmap: Checking correlation matrices for the target length of stay after encoding the features. The results were as follows:
#
#                - length_of_stay                               1.00
#                - apr_drg_description                          0.46
#                - apr_severity_of_illness_description          0.41
#                - ccs_diagnosis_description                    0.37
#                - ccs_procedure_description                    0.35
#                - apr_risk_of_mortality                        0.35
#                - apr_mdc_description                          0.27
#                - apr_medical_surgical_description_Surgical    0.11
#                - age_group                                    0.11
#                - type_of_admission                            0.04
#                - gender_M                                     0.04
#                - emergency_department_indicator_Y             0.03
#
#    ##### From correlation heat map when there is high correlation between two features we drop the feature with lower correlation with the target length of stay we act like follow:
#
#         * type_of_admission & emergency_department_indicator_Y have corr = 0.5 we drop emergency_department_indicator_Y
#         * apr_drg_description, ccs_diagnosis_description & apr_mdc_description have corr = 0.7 we drop ccs_diagnosis_description , apr_mdc_description.
#         * apr_drg_description & ccs_procedure_description have corr = 0.5  we drop ccs_procedure_description
#         * apr_severity_of_illness_description & apr_risk_of_mortality have corr = 0.7 we drop apr_risk_of_mortality
#
#         * Saving a dictionary for categorical features that will be needed in the model deployment step.
# ---
# ### 6. After checking for duplication after all of the above process we found:
#      1) After step 1 droping the irrelevant features, (1,264,916) duplicates appears in the data we drop them.
#      2) After step 2 we drop (342,237) instants of 0 to 17 patients to maintain the data sets for adult patients.
#      3) After dropping highly correlated features we found (580,931) duplicated value. we drop all of it and rest the index.
# ---
# ### 7. Saving the preprocessed, encoded, and scaled CSV file for the next modeling step.
