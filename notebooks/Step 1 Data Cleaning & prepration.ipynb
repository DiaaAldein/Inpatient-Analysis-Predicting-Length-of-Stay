# %% [markdown]
# #               Inpatient Analysis & Predicting Length of Stay
# ##                                Data Science Project Proposal
#
#
# #### Project prepared by: Diaa Aldein Alsayed Ibrahim Osman
# #### Prepared for: Epsilon AI Institute
#
#
# Data obtained from https://www.kaggle.com/datasets/jonasalmeida/2015-deidentified-ny-inpatient-discharge-sparcs/data
#
# ## About Dataset
# Public Health Data
# This is the public dataset made available at https://health.data.ny.gov/Health/Hospital-Inpatient-Discharges-SPARCS-De-Identified/82xm-y6g8 by the Dept of Health of New York state. The following description can be found at that page:
#
# * The Statewide Planning and Research Cooperative System (SPARCS) Inpatient De-identified File contains discharge level detail on patient characteristics, diagnoses, treatments, services, and charges. This data file contains basic record level detail for the discharge. The de-identified data file does not contain data that is protected health information (PHI) under HIPAA. The health information is not individually identifiable; all data elements considered identifiable have been redacted. For example, the direct identifiers regarding a date have the day and month portion of the date removed.
# ---
# * The aim of this project is to conduct inpatient analysis and predict the length of stay in the hospital using the parameters likely to be available when the patient is admitted.
# ---
# * The data is unclean, has missing values, and contains 2.35 million rows and 37 columns. It may not be necessary to include all instances and features to achieve the goal of this project.
#
# ## Data Cleaning & preparation Step:

# %%
# Importing necessary libraries
import pandas as pd
import numpy as np
import warnings            
warnings.filterwarnings("ignore")

# %%
# loading the dataset.
df = pd.read_csv('../data/raw/Hospital_Inpatient_Discharges__SPARCS_De-Identified___2015.csv',low_memory=False)

# %%
# veiwing the head of the data the first 5 rows
df.head()
# Out:
#   Health Service Area Hospital County  Operating Certificate Number  \
# 0          Western NY     Cattaraugus                      401001.0
# 1          Western NY     Cattaraugus                      401001.0
# 2          Western NY     Cattaraugus                      401001.0
# 3          Western NY     Cattaraugus                      401001.0
# 4          Western NY      Chautauqua                      602001.0
#
#    Facility Id                  Facility Name Age Group Zip Code - 3 digits  \
# 0         66.0         Olean General Hospital  50 to 69                 147
# 1         66.0         Olean General Hospital  18 to 29                 147
# 2         66.0         Olean General Hospital  30 to 49                 147
# 3         66.0         Olean General Hospital  50 to 69                 147
# 4        103.0  Woman's Christian Association  50 to 69                 147
#
#   Gender   Race          Ethnicity  ... Payment Typology 2 Payment Typology 3  \
# 0      F  White  Not Span/Hispanic  ...                NaN                NaN
# 1      F  White  Not Span/Hispanic  ...                NaN                NaN
# 2      M  White  Not Span/Hispanic  ...                NaN                NaN
# 3      F  White  Not Span/Hispanic  ...                NaN                NaN
# 4      M  White  Not Span/Hispanic  ...                NaN                NaN
#
#   Attending Provider License Number  Operating Provider License Number  \
# 0                          267162.0                                NaN
# 1                          275408.0                                NaN
# 2                          267162.0                                NaN
# 3                          271326.0                                NaN
# 4                          243034.0                                NaN
#
#    Other Provider License Number Birth Weight  Abortion Edit Indicator  \
# 0                            NaN            0                        N
# 1                            NaN            0                        N
# 2                            NaN            0                        N
# 3                            NaN            0                        N
# 4                            NaN            0                        N
#
#   Emergency Department Indicator  Total Charges Total Costs
# 0                              Y       $5620.00    $4561.28
# 1                              Y       $7404.18    $6933.94
# 2                              Y       $7931.28    $7154.85
# 3                              Y      $11304.44    $4584.11
# 4                              Y       $8330.50    $4361.74
#
# [5 rows x 37 columns]

# %%
# Geitting Information about the Data
df.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2346760 entries, 0 to 2346759
# Data columns (total 37 columns):
#  #   Column                               Non-Null Count    Dtype
# ---  ------                               --------------    -----
#  0   Health Service Area                  2343849 non-null  object
#  1   Hospital County                      2343849 non-null  object
#  2   Operating Certificate Number         2343849 non-null  float64
#  3   Facility Id                          2343849 non-null  float64
#  4   Facility Name                        2346760 non-null  object
#  5   Age Group                            2346760 non-null  object
#  6   Zip Code - 3 digits                  2342333 non-null  object
#  7   Gender                               2346760 non-null  object
#  8   Race                                 2346760 non-null  object
#  9   Ethnicity                            2346760 non-null  object
#  10  Length of Stay                       2346760 non-null  object
#  11  Type of Admission                    2346760 non-null  object
#  12  Patient Disposition                  2346760 non-null  object
#  13  Discharge Year                       2346760 non-null  int64
#  14  CCS Diagnosis Code                   2346760 non-null  int64
#  15  CCS Diagnosis Description            2346760 non-null  object
#  16  CCS Procedure Code                   2346760 non-null  int64
#  17  CCS Procedure Description            2346760 non-null  object
#  18  APR DRG Code                         2346760 non-null  int64
#  19  APR DRG Description                  2346760 non-null  object
#  20  APR MDC Code                         2346760 non-null  int64
#  21  APR MDC Description                  2346760 non-null  object
#  22  APR Severity of Illness Code         2346760 non-null  int64
#  23  APR Severity of Illness Description  2346648 non-null  object
#  24  APR Risk of Mortality                2346648 non-null  object
#  25  APR Medical Surgical Description     2346760 non-null  object
#  26  Payment Typology 1                   2346760 non-null  object
#  27  Payment Typology 2                   1584414 non-null  object
#  28  Payment Typology 3                   701190 non-null   object
#  29  Attending Provider License Number    2343849 non-null  float64
#  30  Operating Provider License Number    1733912 non-null  float64
#  31  Other Provider License Number        71336 non-null    float64
#  32  Birth Weight                         2346760 non-null  int64
#  33  Abortion Edit Indicator              2346760 non-null  object
#  34  Emergency Department Indicator       2346760 non-null  object
#  35  Total Charges                        2346760 non-null  object
#  36  Total Costs                          2346760 non-null  object
# dtypes: float64(5), int64(7), object(25)
# memory usage: 662.5+ MB

# %%
# Modifing columns name
df.columns = df.columns.str.strip().str.lower().str.replace(" ","_").str.replace("-","")
df.columns
# Out:
# Index(['health_service_area', 'hospital_county',
#        'operating_certificate_number', 'facility_id', 'facility_name',
#        'age_group', 'zip_code__3_digits', 'gender', 'race', 'ethnicity',
#        'length_of_stay', 'type_of_admission', 'patient_disposition',
#        'discharge_year', 'ccs_diagnosis_code', 'ccs_diagnosis_description',
#        'ccs_procedure_code', 'ccs_procedure_description', 'apr_drg_code',
#        'apr_drg_description', 'apr_mdc_code', 'apr_mdc_description',
#        'apr_severity_of_illness_code', 'apr_severity_of_illness_description',
#        'apr_risk_of_mortality', 'apr_medical_surgical_description',
#        'payment_typology_1', 'payment_typology_2', 'payment_typology_3',
#        'attending_provider_license_number',
#        'operating_provider_license_number', 'other_provider_license_number',
#        'birth_weight', 'abortion_edit_indicator',
#        'emergency_department_indicator', 'total_charges', 'total_costs'],
#       dtype='object')

# %%
#checking for missing data percentage
df.isnull().mean()*100
# Out:
# health_service_area                     0.124043
# hospital_county                         0.124043
# operating_certificate_number            0.124043
# facility_id                             0.124043
# facility_name                           0.000000
# age_group                               0.000000
# zip_code__3_digits                      0.188643
# gender                                  0.000000
# race                                    0.000000
# ethnicity                               0.000000
# length_of_stay                          0.000000
# type_of_admission                       0.000000
# patient_disposition                     0.000000
# discharge_year                          0.000000
# ccs_diagnosis_code                      0.000000
# ccs_diagnosis_description               0.000000
# ccs_procedure_code                      0.000000
# ccs_procedure_description               0.000000
# apr_drg_code                            0.000000
# apr_drg_description                     0.000000
# apr_mdc_code                            0.000000
# apr_mdc_description                     0.000000
# apr_severity_of_illness_code            0.000000
# apr_severity_of_illness_description     0.004773
# apr_risk_of_mortality                   0.004773
# apr_medical_surgical_description        0.000000
# payment_typology_1                      0.000000
# payment_typology_2                     32.485043
# payment_typology_3                     70.120933
# attending_provider_license_number       0.124043
# operating_provider_license_number      26.114643
# other_provider_license_number          96.960235
# birth_weight                            0.000000
# abortion_edit_indicator                 0.000000
# emergency_department_indicator          0.000000
# total_charges                           0.000000
# total_costs                             0.000000
# dtype: float64

# %% [markdown]
# * As the data contains 2.35 million rows and 37 columns then For any columns that have more than 20% missing values we are going to drop it. Affected columns as follows:
# 1. payment_typology_2 by                     32.490264 %
# 2. payment_typology_3 by                    70.124635 %
# 3. operating_provider_license_number by     26.114227 %
# 4. other_provider_license_number by         96.957239 %
# ---
# * For less than 20 % we are going to drop rows. affected columns as follows:
# 1. health_service_area by                     0.124166 %
# 2. hospital_county  by                        0.124166 %
# 3. operating_certificate_number by            0.124166 %
# 4. facility_id by                             0.124166 %
# 5. zip_code__3_digits by                      0.188744 %
# 6. apr_severity_of_illness_description by     0.004777 %
# 7. apr_risk_of_mortality by                   0.004777 %
# 8. attending_provider_license_number by       0.124166 %

# %%
df.drop(['payment_typology_2','payment_typology_3','operating_provider_license_number','other_provider_license_number'],axis=1,inplace=True)

# %%
df.dropna(axis=0,inplace=True)

# %%
#checking for missing data percentage
df.isnull().mean()*100
# Out:
# health_service_area                    0.0
# hospital_county                        0.0
# operating_certificate_number           0.0
# facility_id                            0.0
# facility_name                          0.0
# age_group                              0.0
# zip_code__3_digits                     0.0
# gender                                 0.0
# race                                   0.0
# ethnicity                              0.0
# length_of_stay                         0.0
# type_of_admission                      0.0
# patient_disposition                    0.0
# discharge_year                         0.0
# ccs_diagnosis_code                     0.0
# ccs_diagnosis_description              0.0
# ccs_procedure_code                     0.0
# ccs_procedure_description              0.0
# apr_drg_code                           0.0
# apr_drg_description                    0.0
# apr_mdc_code                           0.0
# apr_mdc_description                    0.0
# apr_severity_of_illness_code           0.0
# apr_severity_of_illness_description    0.0
# apr_risk_of_mortality                  0.0
# apr_medical_surgical_description       0.0
# payment_typology_1                     0.0
# attending_provider_license_number      0.0
# birth_weight                           0.0
# abortion_edit_indicator                0.0
# emergency_department_indicator         0.0
# total_charges                          0.0
# total_costs                            0.0
# dtype: float64

# %%
pd.set_option('display.max_columns', None)  # This will display all columns

# %%
df.head()
# Out:
#   health_service_area hospital_county  operating_certificate_number  \
# 0          Western NY     Cattaraugus                      401001.0
# 1          Western NY     Cattaraugus                      401001.0
# 2          Western NY     Cattaraugus                      401001.0
# 3          Western NY     Cattaraugus                      401001.0
# 4          Western NY      Chautauqua                      602001.0
#
#    facility_id                  facility_name age_group zip_code__3_digits  \
# 0         66.0         Olean General Hospital  50 to 69                147
# 1         66.0         Olean General Hospital  18 to 29                147
# 2         66.0         Olean General Hospital  30 to 49                147
# 3         66.0         Olean General Hospital  50 to 69                147
# 4        103.0  Woman's Christian Association  50 to 69                147
#
#   gender   race          ethnicity length_of_stay type_of_admission  \
# 0      F  White  Not Span/Hispanic              5         Emergency
# 1      F  White  Not Span/Hispanic              8         Emergency
# 2      M  White  Not Span/Hispanic              8         Emergency
# 3      F  White  Not Span/Hispanic              4         Emergency
# 4      M  White  Not Span/Hispanic              3         Emergency
#
#   patient_disposition  discharge_year  ccs_diagnosis_code  \
# 0   Home or Self Care            2015                 657
# 1   Home or Self Care            2015                 657
# 2   Home or Self Care            2015                 657
# 3   Home or Self Care            2015                 128
# 4   Home or Self Care            2015                  83
#
#   ccs_diagnosis_description  ccs_procedure_code ccs_procedure_description  \
# 0            Mood disorders                   0                   NO PROC
# 1            Mood disorders                   0                   NO PROC
# 2            Mood disorders                   0                   NO PROC
# 3                    Asthma                   0                   NO PROC
# 4     Epilepsy; convulsions                   0                   NO PROC
#
#    apr_drg_code apr_drg_description  apr_mdc_code  \
# 0           753   Bipolar disorders            19
# 1           753   Bipolar disorders            19
# 2           753   Bipolar disorders            19
# 3           141              Asthma             4
# 4            53             Seizure             1
#
#                                 apr_mdc_description  \
# 0                     Mental Diseases and Disorders
# 1                     Mental Diseases and Disorders
# 2                     Mental Diseases and Disorders
# 3  Diseases and Disorders of the Respiratory System
# 4      Diseases and Disorders of the Nervous System
#
#    apr_severity_of_illness_code apr_severity_of_illness_description  \
# 0                             1                               Minor
# 1                             2                            Moderate
# 2                             1                               Minor
# 3                             1                               Minor
# 4                             2                            Moderate
#
#   apr_risk_of_mortality apr_medical_surgical_description payment_typology_1  \
# 0                 Minor                          Medical           Medicaid
# 1                 Minor                          Medical           Medicaid
# 2                 Minor                          Medical           Medicaid
# 3                 Minor                          Medical           Medicare
# 4              Moderate                          Medical           Medicaid
#
#    attending_provider_license_number  birth_weight abortion_edit_indicator  \
# 0                           267162.0             0                       N
# 1                           275408.0             0                       N
# 2                           267162.0             0                       N
# 3                           271326.0             0                       N
# 4                           243034.0             0                       N
#
#   emergency_department_indicator total_charges total_costs
# 0                              Y      $5620.00    $4561.28
# 1                              Y      $7404.18    $6933.94
# 2                              Y      $7931.28    $7154.85
# 3                              Y     $11304.44    $4584.11
# 4                              Y      $8330.50    $4361.74

# %%
# checking features unique values.
for i in list(df.columns):
    print(i)
    print(df[i].unique())
    print("*"*100)
# Out:
# health_service_area
# ['Western NY' 'Finger Lakes' 'Central NY' 'Southern Tier' 'Capital/Adiron'
#  'Hudson Valley' 'New York City' 'Long Island']
# ****************************************************************************************************
# hospital_county
# ['Cattaraugus' 'Chautauqua' 'Erie' 'Genesee' 'Niagara' 'Chemung'
#  'Livingston' 'Monroe' 'Ontario' 'Steuben' 'Wayne' 'Yates' 'Oswego'
#  'Broome' 'Cayuga' 'Chenango' 'Cortland' 'Herkimer' 'Jefferson' 'Lewis'
#  'Madison' 'Oneida' 'Onondaga' 'St Lawrence' 'Tompkins' 'Albany' 'Clinton'
#  'Columbia' 'Franklin' 'Fulton' 'Montgomery' 'Otsego' 'Rensselaer'
#  'Saratoga' 'Schenectady' 'Warren' 'Dutchess' 'Orange' 'Putnam' 'Rockland'
#  'Sullivan' 'Ulster' 'Westchester' 'Bronx' 'Kings' 'Manhattan' 'Richmond'
#  'Queens' 'Suffolk' 'Nassau' 'Allegany' 'Wyoming' 'Orleans' 'Schuyler'
#  'Delaware' 'Essex' 'Schoharie']
# ****************************************************************************************************
# operating_certificate_number
# [ 401001.  602001. 1401014. 1401005. 1401008. 1401013. 1404000. 1427000.
#  1801000. 3102000.  701000.  701001. 2527000. 2701001. 2701003. 2754001.
#  2701005. 3402000. 3421000. 3429000. 5001000. 5002001. 5022000. 5820000.
#  6120700. 3702000.  301001.  303001.  501000.  824000. 1101000. 2129700.
#  2201000. 2238700. 2424700. 2601001. 2625700. 3201002. 3202002. 3202003.
#  3301007. 3301003. 3301008. 4401000. 4402000. 4423701. 4429000. 5401001.
#   101000.  101003.  101004.  901001. 1001000. 1624000. 1701000. 2801001.
#  3801000. 3824000. 4102003. 4102002. 4501000. 4601001. 5601000. 5957001.
#  1302001. 1327000. 3522000. 3523000. 3529000. 3535001. 3950000. 4324000.
#  4329000. 5263000. 5501001. 5526700. 5901000. 5902001. 7002054. 5903001.
#  5904001. 5907001. 5907002. 5920000. 5922000. 5932000. 7000001. 7000002.
#  7000006. 7000008. 7000011. 7000014. 7000024. 7001002. 7001003. 7001009.
#  7001016. 7001019. 7002053. 7001020. 7001021. 7001046. 7001033. 7001035.
#  7001037. 7002002. 7001045. 7002001. 7002009. 7002017. 7002020. 7002021.
#  7002024. 7002032. 7004010. 7003000. 7003001. 7003003. 7003004. 7003007.
#  7001024. 7003010. 7003013. 7004003. 5151001. 2901000. 2908000. 2909000.
#  2910000. 2950001. 2950002. 2951001. 2952006. 2952005. 2953000. 5123000.
#  5126000. 5127000. 5149000. 5149001. 5153000. 5154000. 5154001. 5155000.
#   601000.  427000. 5157003.  226700.  228000.  632000. 1401010. 6027000.
#  3622700. 3101000. 3121001. 4823700. 2701006. 2221700. 4458701. 1229700.
#  1623001. 1254700. 1226701. 1564701. 1552701. 4601004. 4720001. 4102004.
#  1302000. 4322000. 4353000. 5263700. 5501000. 5902002. 5957000. 7001008.
#  7002012. 7002050. 7002026.]
# ****************************************************************************************************
# facility_id
# [6.600e+01 1.030e+02 2.070e+02 2.080e+02 2.100e+02 2.130e+02 2.180e+02
#  2.670e+02 2.800e+02 2.920e+02 3.390e+02 5.740e+02 1.160e+02 1.180e+02
#  3.930e+02 4.090e+02 4.110e+02 4.120e+02 4.130e+02 4.710e+02 6.710e+02
#  6.760e+02 6.780e+02 8.660e+02 8.700e+02 8.730e+02 1.028e+03 1.158e+03
#  1.200e+01 4.300e+01 5.800e+01 8.500e+01 1.280e+02 1.580e+02 3.620e+02
#  3.670e+02 3.790e+02 3.830e+02 3.970e+02 4.010e+02 5.890e+02 5.980e+02
#  5.990e+02 6.280e+02 6.300e+02 6.350e+02 6.360e+02 7.270e+02 7.980e+02
#  8.040e+02 8.120e+02 8.150e+02 9.770e+02 1.000e+00 4.000e+00 5.000e+00
#  1.350e+02 1.460e+02 3.250e+02 3.300e+02 4.840e+02 7.390e+02 7.460e+02
#  7.550e+02 7.560e+02 8.180e+02 8.290e+02 1.005e+03 1.800e+02 1.810e+02
#  1.920e+02 6.940e+02 6.990e+02 7.040e+02 7.080e+02 7.520e+02 7.760e+02
#  7.790e+02 9.710e+02 9.900e+02 1.002e+03 1.039e+03 1.045e+03 1.047e+03
#  1.061e+03 1.072e+03 1.097e+03 1.098e+03 1.117e+03 1.122e+03 1.129e+03
#  1.133e+03 1.139e+03 1.164e+03 1.165e+03 1.168e+03 1.169e+03 1.172e+03
#  1.175e+03 1.176e+03 1.178e+03 1.186e+03 1.286e+03 1.288e+03 1.294e+03
#  1.301e+03 1.304e+03 1.305e+03 1.306e+03 1.309e+03 1.315e+03 1.318e+03
#  1.320e+03 1.324e+03 1.692e+03 1.437e+03 1.438e+03 1.439e+03 1.445e+03
#  1.450e+03 1.453e+03 1.454e+03 1.456e+03 1.458e+03 1.463e+03 1.464e+03
#  1.466e+03 3.975e+03 1.473e+03 1.626e+03 1.628e+03 1.629e+03 1.630e+03
#  1.633e+03 1.635e+03 1.637e+03 1.638e+03 1.737e+03 1.738e+03 1.740e+03
#  3.376e+03 2.450e+02 4.900e+02 5.110e+02 5.130e+02 5.180e+02 5.270e+02
#  5.280e+02 5.410e+02 5.500e+02 5.510e+02 5.520e+02 5.630e+02 8.850e+02
#  8.890e+02 8.910e+02 8.950e+02 8.960e+02 9.130e+02 9.240e+02 9.250e+02
#  9.380e+02 9.800e+01 1.140e+02 9.430e+02 3.700e+01 3.900e+01 1.020e+02
#  1.110e+02 2.160e+02 1.153e+03 5.810e+02 7.180e+02 5.650e+02 3.067e+03
#  3.400e+02 5.830e+02 9.431e+03 8.580e+02 4.140e+02 5.785e+03 4.200e+01
#  3.770e+02 8.170e+02 9.059e+03 2.000e+00 1.740e+02 3.240e+02 1.650e+02
#  1.700e+02 3.090e+02 3.030e+02 4.820e+02 8.310e+02 8.480e+02 8.510e+02
#  9.250e+03 7.750e+02 7.930e+02 9.680e+02 9.890e+02 1.046e+03 1.099e+03
#  1.124e+03 1.138e+03 3.058e+03 1.293e+03 1.446e+03 1.447e+03 1.486e+03
#  1.460e+03 1.469e+03 1.639e+03]
# ****************************************************************************************************
# facility_name
# ['Olean General Hospital' "Woman's Christian Association"
#  'Buffalo General Hospital' "Women And Children's Hospital Of Buffalo"
#  'Erie County Medical Center' 'Mercy Hospital of Buffalo'
#  'Sisters of Charity Hospital' 'Kenmore Mercy Hospital'
#  'Bertrand Chaffee Hospital'
#  'Sisters of Charity Hospital - St Joseph Campus'
#  'United Memorial Medical Center North Street Campus'
#  'Niagara Falls Memorial Medical Center' 'Arnot Ogden Medical Center'
#  'St Josephs Hospital' 'Nicholas H Noyes Memorial Hospital'
#  'Highland Hospital' 'Rochester General Hospital'
#  'The Unity Hospital of Rochester-St Marys Campus'
#  'Strong Memorial Hospital' 'The Unity Hospital of Rochester'
#  'Geneva General Hospital' 'Clifton Springs Hospital and Clinic'
#  'F F Thompson Hospital' 'Corning Hospital' 'St James Mercy Hospital'
#  'Ira Davenport Memorial Hospital Inc' 'Newark-Wayne Community Hospital'
#  'Soldiers and Sailors Memorial Hospital of Yates County Inc'
#  'Oswego Hospital - Alvin L Krakau Comm Mtl Health Center Div'
#  'Our Lady of Lourdes Memorial Hospital Inc'
#  'United Health Services Hospitals Inc. - Wilson Medical Center'
#  'Auburn Memorial Hospital' 'Chenango Memorial Hospital Inc'
#  'Cortland Regional Medical Center Inc' 'Little Falls Hospital'
#  'Samaritan Medical Center' 'Carthage Area Hospital Inc'
#  'Lewis County General Hospital' 'Oneida Healthcare Center'
#  'Community Memorial Hospital Inc' 'Rome Memorial Hospital, Inc'
#  'St Elizabeth Medical Center'
#  'Faxton-St Lukes Healthcare St Lukes Division'
#  'UPSTATE University Hospital at Community General'
#  'St Josephs Hospital Health Center'
#  'University Hospital SUNY Health Science Center' 'Crouse Hospital'
#  'Oswego Hospital' 'Claxton-Hepburn Medical Center'
#  'Massena Memorial Hospital' 'Gouverneur Hospital'
#  'Canton-Potsdam Hospital' 'Cayuga Medical Center at Ithaca'
#  'Albany Medical Center Hospital' 'Albany Memorial Hospital'
#  'St Peters Hospital'
#  'The University of Vermont Health Network - Champlain Valley Physicians'
#  'Columbia Memorial Hospital' 'Alice Hyde Medical Center'
#  'Nathan Littauer Hospital' "St. Mary's Healthcare"
#  'Aurelia Osborn Fox Memorial Hospital' 'Mary Imogene Bassett Hospital'
#  'Seton Health System - St Marys Campus' 'Samaritan Hospital'
#  'Saratoga Hospital' 'Ellis Hospital' 'Glens Falls Hospital'
#  'Mid-Hudson Valley Division of Westchester Medical Center'
#  'Vassar Brothers Medical Center' 'Northern Dutchess Hospital'
#  "St Luke's Cornwall Hospital/Newburgh"
#  'Orange Regional Medical Center-Goshen Campus'
#  'St Anthony Community Hospital' 'Bon Secours Community Hospital'
#  'Putnam Hospital Center' 'Nyack Hospital'
#  'Good Samaritan Hospital of Suffern' 'Catskill Regional Medical Center'
#  'HealthAlliance Hospital Broadway Campus' 'Ellenville Regional Hospital'
#  'NewYork-Presbyterian/Hudson Valley Hospital'
#  'White Plains Hospital Center'
#  'New York Presbyterian Hospital - Westchester Division'
#  'Montefiore Mount Vernon Hospital' 'Montefiore New Rochelle Hospital'
#  'SJRH - St Johns Division' "St Joseph's Medical Center"
#  'Northern Westchester Hospital' 'New York-Presbyterian/Lawrence Hospital'
#  'Phelps Memorial Hospital Assn'
#  "St Joseph's MC-St Vincents Westchester Division"
#  'Westchester Medical Center'
#  'Bronx-Lebanon Hospital Center - Fulton Division' 'Jacobi Medical Center'
#  'Montefiore Medical Center-Wakefield Hospital'
#  'Montefiore Medical Center - Henry & Lucy Moses Div'
#  'Lincoln Medical & Mental Health Center' 'Calvary Hospital Inc'
#  'SBH Health System' 'Bronx-Lebanon Hospital Center - Concourse Division'
#  'North Central Bronx Hospital' 'Brookdale Hospital Medical Center'
#  'Brooklyn Hospital Center - Downtown Campus' 'Coney Island Hospital'
#  'Kings County Hospital Center' 'NYU Lutheran Medical Center'
#  'Maimonides Medical Center' 'New York Methodist Hospital'
#  'Interfaith Medical Center' 'Kingsbrook Jewish Medical Center'
#  'Wyckoff Heights Medical Center' 'University Hospital of Brooklyn'
#  'Mount Sinai Beth Israel Brooklyn'
#  'Woodhull Medical & Mental Health Center'
#  'New York-Presbyterian/Lower Manhattan Hospital'
#  'Bellevue Hospital Center' 'Mount Sinai Beth Israel'
#  'Harlem Hospital Center' 'Lenox Hill Hospital'
#  'Memorial Hospital for Cancer and Allied Diseases'
#  'Metropolitan Hospital Center' 'Mount Sinai Hospital'
#  'New York Presbyterian Hospital - New York Weill Cornell Center'
#  'NYU Hospitals Center'
#  'New York Presbyterian Hospital - Columbia Presbyterian Center'
#  'Mount Sinai Roosevelt' 'New York Presbyterian Hospital - Allen Hospital'
#  'RUMC-Bayley Seton' 'Elmhurst Hospital Center'
#  'Flushing Hospital Medical Center' 'Jamaica Hospital Medical Center'
#  'Long Island Jewish Medical Center' 'Queens Hospital Center'
#  'St Johns Episcopal Hospital So Shore'
#  'New York Hospital Medical Center of Queens' 'Forest Hills Hospital'
#  'Staten Island University Hosp-South'
#  'Richmond University Medical Center'
#  'Staten Island University Hosp-North'
#  "Long Island Jewish Schneiders Children's Hospital Division"
#  'University Hospital' 'Glen Cove Hospital' 'Winthrop-University Hospital'
#  'Mercy Medical Center' 'Franklin Hospital'
#  'Long Island Jewish Valley Stream' 'South Nassau Communities Hospital'
#  'Nassau University Medical Center' 'North Shore University Hospital'
#  'Syosset Hospital' 'St. Joseph Hospital' 'Plainview Hospital'
#  'St Francis Hospital' 'Brookhaven Memorial Hospital Medical Center Inc'
#  'Southampton Hospital' 'Eastern Long Island Hospital'
#  'John T Mather Memorial Hospital of Port Jefferson New York Inc'
#  'St Charles Hospital' 'Huntington Hospital' 'Southside Hospital'
#  'Good Samaritan Hospital Medical Center' 'Peconic Bay Medical Center'
#  'Brooks Memorial Hospital' 'TLC Health Network Lake Shore Hospital'
#  'St Catherine of Siena Hospital' 'Cuba Memorial Hospital Inc'
#  'Memorial Hosp of Wm F & Gertrude F Jones A/K/A Jones Memorial Hosp'
#  'Womans Christian Assoc Hospital - WCA Hosp at Jones Memorial Health Ce'
#  'Westfield Memorial Hospital Inc' 'Roswell Park Cancer Institute'
#  'Wyoming County Community Hospital' 'Degraff Memorial Hospital'
#  'Medina Memorial Hospital' 'Eastern Niagara Hospital - Lockport Division'
#  'Millard Fillmore Suburban Hospital'
#  'United Memorial Medical Center Bank Street Campus'
#  'Mount St Marys Hospital and Health Center'
#  "St. Peter's Addiction Recovery Center" 'Schuyler Hospital'
#  'Monroe Community Hospital' 'St James Mercy Hospital - Mercycare'
#  'United Health Services Hospitals Inc. - Binghamton General Hospital'
#  'River Hospital, Inc.' 'Clifton-Fine Hospital'
#  'Crouse Hospital - Commonwealth Division'
#  'Albany Medical Center - South Clinical Campus'
#  'Delaware Valley Hospital Inc'
#  'Adirondack Medical Center-Saranac Lake Site' "O'Connor Hospital"
#  'Margaretville Hospital' 'Moses-Ludington Hospital'
#  'The University of Vermont Health Network - Elizabethtown Community Hos'
#  "St. Mary's Healthcare - Amsterdam Memorial Campus"
#  'Sunnyview Hospital and Rehabilitation Center'
#  "Ellis Hospital - Bellevue Woman's Care Center Division"
#  'Cobleskill Regional Hospital' 'The Burdett Care Center'
#  'Helen Hayes Hospital' 'Summit Park Hospital-Rockland County Infirmary'
#  'Catskill Regional Medical Center - G. Hermann Site'
#  'HealthAlliance Hospital Marys Avenue Campus'
#  'Winifred Masterson Burke Rehabilitation Hospital'
#  'SJRH - Park Care Pavilion' 'SJRH - Dobbs Ferry Pavillion'
#  'Blythedale Childrens Hospital'
#  'Montefiore Med Center - Jack D Weiler Hosp of A Einstein College Div'
#  'New York Community Hospital of Brooklyn, Inc'
#  'NYU Hospital for Joint Diseases' 'Hospital for Special Surgery'
#  'Henry J. Carter Specialty Hospital'
#  'New York Eye and Ear Infirmary of Mount Sinai' 'Mount Sinai St. Lukes'
#  'Mount Sinai Hospital - Mount Sinai Hospital of Queens']
# ****************************************************************************************************
# age_group
# ['50 to 69' '18 to 29' '30 to 49' '70 or Older' '0 to 17']
# ****************************************************************************************************
# zip_code__3_digits
# ['147' '141' '142' '143' '140' 'OOS' '148' '146' '145' '144' '149' '130'
#  '131' '139' '137' '138' '136' '117' '133' '134' '132' '135' '123' '128'
#  '122' '121' '120' '124' '104' '125' '129' '116' '110' '126' '109' '127'
#  '105' '106' '108' '100' '112' '107' '114' '113' '111' '103' '115' '119'
#  '101' '118']
# ****************************************************************************************************
# gender
# ['F' 'M' 'U']
# ****************************************************************************************************
# race
# ['White' 'Other Race' 'Black/African American' 'Multi-racial']
# ****************************************************************************************************
# ethnicity
# ['Not Span/Hispanic' 'Unknown' 'Spanish/Hispanic' 'Multi-ethnic']
# ****************************************************************************************************
# length_of_stay
# ['5' '8' '4' '3' '2' '9' '1' '59' '10' '17' '35' '15' '12' '7' '98' '26'
#  '6' '46' '32' '16' '21' '22' '13' '77' '14' '58' '28' '11' '18' '19' '29'
#  '27' '42' '24' '23' '31' '37' '57' '25' '20' '30' '63' '43' '49' '45'
#  '102' '56' '33' '40' '34' '55' '100' '47' '38' '61' '53' '117' '62'
#  '120 +' '80' '48' '70' '44' '51' '41' '64' '50' '36' '107' '68' '74' '39'
#  '87' '83' '54' '105' '81' '112' '76' '91' '86' '66' '72' '94' '93' '67'
#  '69' '73' '119' '115' '75' '97' '92' '95' '60' '65' '82' '79' '71' '84'
#  '109' '103' '118' '52' '101' '85' '110' '106' '88' '111' '104' '89' '78'
#  '116' '90' '113' '108' '114' '96' '99']
# ****************************************************************************************************
# type_of_admission
# ['Emergency' 'Urgent' 'Elective' 'Not Available' 'Trauma' 'Newborn']
# ****************************************************************************************************
# patient_disposition
# ['Home or Self Care' 'Skilled Nursing Home' 'Home w/ Home Health Services'
#  'Short-term Hospital' 'Court/Law Enforcement' 'Expired'
#  'Left Against Medical Advice' 'Hospice - Home' 'Another Type Not Listed'
#  'Psychiatric Hospital or Unit of Hosp'
#  'Facility w/ Custodial/Supportive Care'
#  'Inpatient Rehabilitation Facility' 'Federal Health Care Facility'
#  'Hospice - Medical Facility' 'Hosp Basd Medicare Approved Swing Bed'
#  "Cancer Center or Children's Hospital"
#  'Medicare Cert Long Term Care Hospital' 'Critical Access Hospital'
#  'Medicaid Cert Nursing Facility']
# ****************************************************************************************************
# discharge_year
# [2015]
# ****************************************************************************************************
# ccs_diagnosis_code
# [657 128  83 102  98 123 103 159 251  48  42 157 112 109 654 125 184 240
#  138   7 659 181 245 185 189 143 187  84  95 100  19 670   5 651  50  14
#  146 145 660 192  15 140  13 193 108 106 117 153 233 133  56 135 105  36
#  120 246 155 656 224 248 142  82 194 196 218 154  39 230 650   4 199   2
#  180  91 661  88 158 247  86 190  99   1  51 228  24 147   6 652  49  12
#  231  32  55 662 259 122 127 126 197 124 152  93 129 211 244 175 186 234
#  131 237  43 195 242 238 188 130 149 167 139 191 151  46 137 183 118  58
#  226 160  60 222 253  59 182  81 134 241 141 101  27 168 205  63  54  44
#  144 163 169  26  47  18 114 201 250 203  11  96 236 171 653 207 162 204
#  116  25 170 164 110 663 107 229 252  62  61 173  16  57  80  97 172 243
#  232 219 121 165  94 658 239 104 198 235  33  76  38 115   3  17 213  85
#  161 212  79 917 156 209 200 225 148 119 166 132 217  90 202 255 254  29
#   34 113  20 111  92  52  40 257   9 249  89 655  41  64 210   8  35 216
#   22  21 227  78  23  87  77 258 215 179 214 136 206  37  10  53 220 221
#   45 256 223 178 208  31  28  30 174 177 176]
# ****************************************************************************************************
# ccs_diagnosis_description
# ['Mood disorders' 'Asthma' 'Epilepsy; convulsions'
#  'Nonspecific chest pain' 'Essential hypertension' 'Influenza'
#  'Pulmonary heart disease' 'Urinary tract infections' 'Abdominal pain'
#  'Thyroid disorders' 'Secondary malignancies'
#  'Acute and unspecified renal failure' 'Transient cerebral ischemia'
#  'Acute cerebrovascular disease' 'Developmental disorders'
#  'Acute bronchitis' 'Early or threatened labor' 'Burns'
#  'Esophageal disorders' 'Viral infection'
#  'Schizophrenia and other psychotic disorders'
#  'Other complications of pregnancy' 'Syncope' 'Prolonged pregnancy'
#  'Previous C-section' 'Abdominal hernia' 'Malposition; malpresentation'
#  'Headache; including migraine' 'Other nervous system disorders'
#  'Acute myocardial infarction' 'Cancer of bronchus; lung'
#  'Miscellaneous disorders' 'HIV infection' 'Anxiety disorders'
#  'Diabetes mellitus with complications' 'Cancer of colon'
#  'Diverticulosis and diverticulitis'
#  'Intestinal obstruction without hernia' 'Alcohol-related disorders'
#  'Umbilical cord complication' 'Cancer of rectum and anus'
#  'Gastritis and duodenitis' 'Cancer of stomach'
#  'OB-related trauma to perineum and vulva'
#  'Congestive heart failure; nonhypertensive' 'Cardiac dysrhythmias'
#  'Other circulatory disease' 'Gastrointestinal hemorrhage'
#  'Intracranial injury' 'Other lower respiratory disease' 'Cystic fibrosis'
#  'Intestinal infection' 'Conduction disorders' 'Cancer of thyroid'
#  'Hemorrhoids' 'Fever of unknown origin'
#  'Other gastrointestinal disorders' 'Impulse control disorders, NEC'
#  'Other perinatal conditions' 'Gangrene'
#  'Appendicitis and other appendiceal conditions' 'Paralysis'
#  'Forceps delivery' 'Other pregnancy and delivery including normal'
#  'Liveborn' 'Noninfectious gastroenteritis' 'Leukemias'
#  'Fracture of lower limb' 'Adjustment disorders' 'Mycoses'
#  'Chronic ulcer of skin' 'Septicemia (except in labor)'
#  'Ectopic pregnancy' 'Other eye disorders' 'Substance-related disorders'
#  'Glaucoma' 'Chronic kidney disease' 'Lymphadenitis' 'Cataract'
#  'Fetal distress and abnormal forces of labor'
#  'Hypertension with complications and secondary hypertension'
#  'Tuberculosis' 'Other endocrine disorders' 'Skull and face fractures'
#  'Cancer of breast' 'Anal and rectal conditions' 'Hepatitis'
#  'Attention-deficit, conduct, and disruptive behavior disorders'
#  'Diabetes mellitus without complication' 'Cancer of esophagus'
#  'Other fractures' 'Cancer of bladder' 'Fluid and electrolyte disorders'
#  'Suicide and intentional self-inflicted injury'
#  'Residual codes; unclassified'
#  'Pneumonia (except that caused by tuberculosis or sexually transmitted disease)'
#  'Chronic obstructive pulmonary disease and bronchiectasis'
#  'Other upper respiratory infections'
#  'Skin and subcutaneous tissue infections' 'Acute and chronic tonsillitis'
#  'Pancreatic disorders (not diabetes)'
#  'Conditions associated with dizziness or vertigo'
#  'Aspiration pneumonitis; food/vomitus' 'Other connective tissue disease'
#  'Other injuries and conditions due to external causes'
#  'Other female genital disorders'
#  'Diabetes or abnormal glucose tolerance complicating pregnancy; childbirth; or the puerperium'
#  'Crushing injury or internal injury'
#  'Respiratory failure; insufficiency; arrest (adult)'
#  'Complication of device; implant or graft'
#  'Malignant neoplasm without specification of site'
#  'Other complications of birth; puerperium affecting management of mother'
#  'Poisoning by other medications and drugs'
#  'Complications of surgical procedures or medical care'
#  'Fetopelvic disproportion; obstruction'
#  'Pleurisy; pneumothorax; pulmonary collapse' 'Biliary tract disease'
#  'Nonmalignant breast conditions'
#  'Gastroduodenal ulcer (except hemorrhage)'
#  'Polyhydramnios and other problems of amniotic cavity'
#  'Other liver diseases' 'Benign neoplasm of uterus'
#  'Diseases of mouth; excluding dental'
#  'Hypertension complicating pregnancy; childbirth and the puerperium'
#  'Phlebitis; thrombophlebitis and thromboembolism'
#  'Other nutritional; endocrine; and metabolic disorders'
#  'Fracture of neck of femur (hip)' 'Calculus of urinary tract'
#  'Acute posthemorrhagic anemia'
#  'Hemolytic jaundice and perinatal jaundice' 'Allergic reactions'
#  'Deficiency and other anemia'
#  'Hemorrhage during pregnancy; abruptio placenta; placenta previa'
#  'Other hereditary and degenerative nervous system conditions'
#  'Other upper respiratory disease' 'Poisoning by psychotropic agents'
#  'Other disorders of stomach and duodenum'
#  'Coronary atherosclerosis and other heart disease' 'Cancer of ovary'
#  'Inflammatory diseases of female pelvic organs'
#  'Spondylosis; intervertebral disc disorders; other back problems'
#  'Diseases of white blood cells' 'Gout and other crystal arthropathies'
#  'Neoplasms of unspecified nature or uncertain behavior'
#  'Regional enteritis and ulcerative colitis'
#  'Genitourinary symptoms and ill-defined conditions' 'Endometriosis'
#  'Cancer of cervix' 'Other and unspecified benign neoplasm'
#  'Cancer of other GI organs; peritoneum'
#  'Peripheral and visceral atherosclerosis'
#  'Infective arthritis and osteomyelitis (except that caused by tuberculosis or sexually transmitted disease)'
#  'Nausea and vomiting' 'Osteoarthritis' 'Cancer of head and neck'
#  'Heart valve disorders' 'Open wounds of extremities'
#  'Menstrual disorders'
#  'Delirium, dementia, and amnestic and other cognitive disorders'
#  'Pathological fracture' 'Other diseases of bladder and urethra'
#  'Other non-traumatic joint disorders'
#  'Aortic and peripheral arterial embolism or thrombosis'
#  'Cancer of uterus' 'Prolapse of female genital organs'
#  'Hyperplasia of prostate' 'Occlusion or stenosis of precerebral arteries'
#  'Screening and history of mental health and substance abuse codes'
#  'Cardiac arrest and ventricular fibrillation' 'Fracture of upper limb'
#  'Malaise and fatigue' 'Coagulation and hemorrhagic disorders'
#  'Sickle cell anemia' 'Menopausal disorders'
#  'Cancer of liver and intrahepatic bile duct' 'Immunity disorders'
#  'Multiple sclerosis'
#  'Peri-; endo-; and myocarditis; cardiomyopathy (except that caused by tuberculosis or sexually transmitted disease)'
#  'Ovarian cyst' 'Poisoning by nonmedicinal substances'
#  'Sprains and strains'
#  'Short gestation; low birth weight; and fetal growth retardation'
#  'Other diseases of veins and lymphatics'
#  'Inflammatory conditions of male genital organs'
#  'Other ear and sense organ disorders' 'Personality disorders'
#  'Superficial injury; contusion' 'Other and ill-defined heart disease'
#  'Other inflammatory condition of skin'
#  'Open wounds of head; neck; and trunk'
#  'Cancer of kidney and renal pelvis'
#  'Meningitis (except that caused by tuberculosis or sexually transmitted disease)'
#  'Non-Hodgkin`s lymphoma'
#  'Aortic; peripheral; and visceral artery aneurysms'
#  'Bacterial infection; unspecified site' 'Cancer of pancreas'
#  'Cardiac and circulatory congenital anomalies'
#  'Coma; stupor; and brain damage' 'Other diseases of kidney and ureters'
#  'Other bone disease and musculoskeletal deformities'
#  'Parkinson`s disease' 'E Codes: Unclassified'
#  'Nephritis; nephrosis; renal sclerosis' 'Other acquired deformities'
#  'Other skin disorders' 'Joint disorders and dislocations; trauma-related'
#  'Peritonitis and intestinal abscess' 'Varicose veins of lower extremity'
#  'Other male genital disorders' 'Lung disease due to external agents'
#  'Other congenital anomalies'
#  'Inflammation; infection of eye (except that caused by tuberculosis or sexually transmitteddisease)'
#  'Rheumatoid arthritis and related disease'
#  'Administrative/social admission'
#  'Rehabilitation care; fitting of prostheses; and adjustment of devices'
#  'Cancer of prostate' 'Cancer of other urinary organs'
#  'Late effects of cerebrovascular disease'
#  'Cancer; other respiratory and intrathoracic'
#  'Other and ill-defined cerebrovascular disease'
#  'Otitis media and related conditions' 'Nutritional deficiencies'
#  'Multiple myeloma' 'Other aftercare'
#  'Sexually transmitted infections (not HIV or hepatitis)' 'Shock'
#  'Blindness and vision defects'
#  'Disorders usually diagnosed in infancy, childhood, or adolescence'
#  'Cancer; other and unspecified primary' 'Other hematologic conditions'
#  'Systemic lupus erythematosus and connective tissue disorders'
#  'Other infections; including parasitic'
#  'Cancer of brain and nervous system'
#  'Nervous system congenital anomalies' 'Melanomas of skin'
#  'Cancer of bone and connective tissue' 'Spinal cord injury'
#  'Other CNS infection and poliomyelitis'
#  'Other non-epithelial cancer of skin'
#  'Retinal detachments; defects; vascular occlusion; and retinopathy'
#  'Encephalitis (except that caused by tuberculosis or sexually transmitted disease)'
#  'Other screening for suspected conditions (not mental disorders or infectious disease)'
#  'Genitourinary congenital anomalies' 'Postabortion complications'
#  'Digestive congenital anomalies' 'Disorders of teeth and jaw'
#  'Osteoporosis' 'Hodgkin`s disease'
#  'Immunizations and screening for infectious disease'
#  'Disorders of lipid metabolism' 'Intrauterine hypoxia and birth asphyxia'
#  'Respiratory distress syndrome' 'Maintenance chemotherapy; radiotherapy'
#  'Medical examination/evaluation' 'Birth trauma' 'Induced abortion'
#  'Acquired foot deformities' 'Cancer of other male genital organs'
#  'Cancer of other female genital organs' 'Cancer of testis'
#  'Female infertility' 'Spontaneous abortion'
#  'Contraceptive and procreative management']
# ****************************************************************************************************
# ccs_procedure_code
# [  0 216 227 214 231 137 134 203  83 222 140 218 171 139  76  32 169  70
#  178  81 193 133 131  55   4 217 172  80 179 198  92 136   3 135 199  95
#  148  47 219 228  61  78 160 209 177 197 180  58  90  39 215 226  15 201
#  122 183   9  49   1 105 202 144 167  96 196 141  75  85 229 120  54 115
#   27  84 174  94 124 146 225 101  37 127 153 221 163  98 102  93  89 119
#  157 155  71 162 168 142 152  99 147  88 175 123  40 159 173  41 132  74
#  161 170 113  51  86  48  34  45  36 223  63  10 118 111  60  66  77  19
#   38 151  73  72 154  91 108  42 100 112  79 128 129 110 117 107  67 125
#   62  69  97 156 164   5 145 130 220 213 104  65 103 114  87 116 109 189
#  187  31 121  57 211 190  33 204  44  43  59 158 188   8  35   2  52 191
#  181  82   7  50 999  12  56  23   6 166  11 165 185  30 106  46  24 224
#   25 192 200  26 194 210  28 195  29 207 138  21 143  18 184  20 206  14
#  176 149  64 208  68 150 205  17 212  16 126 186  53  13 182  22]
# ****************************************************************************************************
# ccs_procedure_description
# ['NO PROC' 'RESP INTUB/MECH VENTIL' 'OT DX PRC (INTERVW,EVAL'
#  'TRACTN, SPLNT, OT WOUND' 'OTHER THERAPEUTIC PRCS'
#  'OT PRCS TO ASSIST DELIV' 'CESAREAN SECTION' 'ELECTROGR CARDIAC MONIT'
#  'BIOPSY OF LIVER' 'BLOOD TRANSFUSION' 'REPAIR CUR OBS LACERATN'
#  'PSYCHO/PSYCHI EVAL/THER' 'SUTURE SKIN/SUBCUT TISS' 'FETAL MONITORING'
#  'COLONOSCOPY AND BIOPSY' 'OT NON-OR THER PRC NOSE'
#  'DEBRIDE WOUND,INF,BURN' 'UP GASTRO ENDOSC/BIOPSY' 'CT SCAN CHEST'
#  'HEMORRHOID PRCS' 'DX ULTRASOUND HEART' 'EPISIOTOMY'
#  'OT NON-OR THER PRC; FEM' 'PERIPH VASCULAR BYPASS'
#  'DIAGNOSTIC SPINAL TAP' 'OTHER RESP THERAPY' 'SKIN GRAFT' 'APPENDECTOMY'
#  'CT SCAN ABDOMEN' 'MAG RESONANCE IMAGING' 'OTHER BOWEL DX PRCS'
#  'ART RUPT MEMB ASSIS DLV' 'LAMINECTOMY; EXC IV DSC'
#  'FORCEP;VAC;BREACH DELIV' 'ELECTROENCEPHALOGRAM'
#  'OT NON-OR LW GI THER PR' 'OT FRACTURE/DISLOC PRC'
#  'DX CARDIAC CATHETERIZTN' 'ALCO/DRUG REHAB/DETOX'
#  'PROPHYLACTIC VAC/INOCUL' 'OT OR PRCS VES NOT HEAD'
#  'COLORECTAL RESECTION' 'OT THER PRCS ON MUSCLES'
#  'RADIOISOTOPE SCAN/FUNCT' 'COMP AXIAL TOMOGR (CT)' 'OTHER DX ULTRASOUND'
#  'OTHER CT SCAN' 'HEMODIALYSIS' 'EXCISION; LYS PERI ADHS'
#  'INCISION OF PLEURA' 'OT PHYS THER/REHAB' 'OT DX RADIO & RELATED'
#  'LENS & CATARACT PRCS' 'CARDIAC STRESS TESTS' 'RMVL ECTOPIC PREGNANCY'
#  'ROUTINE CHEST X-RAY' 'OTHER OR THER NERV SYS' 'OTHER OR HEART PRCS'
#  'INCISION & EXCISION CNS' 'KIDNEY TRANSPLANT' 'ELECTROCARDIOGRAM'
#  'TRTMNT,FACE FRACT/DISLC' 'MASTECTOMY' 'OT OR LOW GI THER PRCS'
#  'DX ULTRASOUND AB/RETRO' 'OT THER OBSTETRICAL PRC' 'SMALL BOWEL RESECTON'
#  'INGUINAL/FEMORAL HERNIA' 'NONOP RMVL FOREIGN BODY'
#  'OT OPERATIONS ON OVARY' 'OT VASC CATH; NOT HEART' 'CIRCUMCISION'
#  'CONTROL OF EPISTAXIS' 'CHOLECYSTECTOMY/EXPLOR' 'OT NON-OR THER PRC SKIN'
#  'OT OR UP GI THER PRCS' 'HYSTERECTOMY; AB/VAG' 'TRTMNT,FRAC HIP/FEMUR'
#  'CONV OF CARDIAC RHYTHM' 'TRANSURETHRAL EXCISION'
#  'DX BRONCHOSCOPY & BIOPS' 'D&C; ASPIR AFT DLV/ABOR'
#  'HIP REPLACEMENT,TOT/PRT' 'NASOGASTRIC TUBE' 'OT NON-OR THER PRC MUSC'
#  'OT NON-OR GI THER PRCS' 'URETERAL CATHETERIZATN'
#  'OT NON-OR UP GI THER PR' 'EXPLORATORY LAPAROTOMY'
#  'OOPHORECTOMY; UNI/BILAT' 'AMPUTATE LOWER EXTRMITY' 'ARTHROCENTESIS'
#  'GASTROSTOMY; TEMP/PERM' 'OT OR THER PRC ON JOINT'
#  'INCIS/DRAIN, SKIN/SUBCU' 'PARTIAL EXCISION BONE' 'ARTHROPLASTY KNEE'
#  'OT OR GI THER PRCS' 'TRTMNT,FRAC LOWR EXTREM' 'ABDOMINAL PARACENTESIS'
#  'OT OR THER PRC SKN/BRST' 'OT OPER FALLOPIAN TUBES'
#  'OT DX PRCS OF RESP TRCT' 'OT DX PRCS ON MUSC/SKEL'
#  'OT DX PRC SKIN/SUBCUTAN' 'OT NON-OR THER PRC RESP'
#  'OT OR THER PRC; FEM ORG' 'GASTRECTOMY; PART/TOTAL'
#  'OT OR THER PRCS ON BONE' 'EXCISION OF SKIN LESION'
#  'TRANS RES PROSTATE-TURP' 'ENDARTERECTOMY;VES HEAD' 'OTHER HERNIA REPAIR'
#  'CARDIAC PACEMAKER/DEFIB' 'TRACHEOSTOMY; TEMP/PERM'
#  'PERC TRANSLUM COR ANGIO' 'LOBECTOMY/PNEUMONECTOMY'
#  'ENTERAL/PARENTERAL NUTR' 'OT NON-OR THER CARDIO'
#  'THYROIDECTOMY;PART/FULL' 'OT OR THER PRCS; MALE'
#  'OT NON-OR THER PRC URIN' 'EMBOL-/ENDARTER-ECTOMY' 'PRCS ON SPLEEN'
#  'PROCTOSCOPY & AR BIOPSY' 'OT THER PRCS EYELIDS' 'OT DX PRCS ON LUNG'
#  'EXC OF SEMI CART KNEE' 'ILEO- & OT ENTER-OSTOMY' 'COLOSTOMY; TEMP/PERM'
#  'ARTHROPLASTY-NOT HIP/KN' 'PERITONEAL DIALYSIS' 'INDWELLING CATHETER'
#  'OT OR RX PRCS RESP SYS' 'ENDOSCOPY URINARY TRACT'
#  'OT OR THER PRCS URINARY' 'LOC EXC LRG INTEST LESN'
#  'DX DILAT/CURETTAGE -D&C' 'REPAIR CYST-/RECT-OCELE'
#  'OT DX PRCS URINARY TRCT' 'OT NON-OR THER PRCS; M'
#  'EXTRACORP LTIHO;URINARY' 'OT THER PRCS; HEM/LYMPH'
#  'OT EXC CERVIX & UTERUS' 'OT DX CARDIOVASC PRCS' 'ESOPHAGEAL DILATATION'
#  'OTHER GI DX PRCS' 'INJ/ASP MUSC,TENDONS,ST' 'OT OR THER PRC MUSC/SKL'
#  'INS CATHETER/SPNL STIM' 'TRTMNT,FRAC RADIUS/ULNA'
#  'OT DX PRCS; FEMALE ORGN' 'OPHTHALM-/OT-OLOGIC DX'
#  'PHYS THER EXER, MANIPUL' 'NEPHRECTOMY; PART/TOTAL' 'BONE MARROW BIOPSY'
#  'NEPHRO-/NEPHROS-TOMY' 'OPEN PROSTATECTOMY' 'LAPAROSCOPY'
#  'DX PRCS; MALE GENITAL' 'PRCS ON THE URETHRA' 'CONTRAST AORTOGRAM'
#  'INTRAVENOUS PYELOGRAM' 'DX PRCS ON NOSE & MOUTH'
#  'LIG/OCCL FALLOPIAN TUBE' 'ARTERIOVENOUS FISTULA' 'THERAPEUTIC RADIOLOGY'
#  'ARTERIO FEMORAL/LOW ART' 'OTHER OR THER PRCS NOSE'
#  'SWAN-GANZ CATH MONITOR' 'COR ARTERY BYP GRF-CABG' 'HEART VALVE PRCS'
#  'OT OR PRCS ON VES HEAD' 'SPINAL FUSION' 'CEREBRAL ARTERIOGRAM'
#  'OT NON-OR THER NERV SYS' 'TRACHE-/LARYNG-OSCOPY'
#  'IRR XCRANIAL VENT SHUNT' 'AORTIC RESECTION; REPL'
#  'ARTERIO/VENOGRAM-NOT HH' 'MYELOGRAM' 'ENDO RETRO CAN OF PANCR'
#  'OTHER DX NERV SYS PRCS' 'EXTRA CIRC AUX OPEN HRT' 'UNGROUPABLE'
#  'OT THER ENDOCRINE PRCS' 'OT VASCULAR BYP/SHUNT' 'MYRINGOTOMY'
#  'DECOMP PERIPHERAL NERVE' 'LUMPECTOMY, QUAD BREAST' 'DX ENDOCRINE PRCS'
#  'BREAST BIOPSY & DX PRCS' 'UPPER GI X-RAY' 'TONSIL-/ADENOID-ECTOMY'
#  'GENI INCONTINENCE PRCS' 'CORONARY THROMBOLYSIS' 'MASTOIDECTOMY'
#  'CANCER CHEMOTHERAPY' 'DX PRCS ON EAR' 'DX ULTRASOUND HEAD/NECK'
#  'NONOP URINARY SYS MEASR' 'OT THERAPEUTIC EAR PRCS' 'DX ULTRASOUND OF GI'
#  'OTHER RADIOISOTOPE SCAN' 'PLASTIC PRCS ON NOSE' 'DX ULTRASOUND URINARY'
#  'ORAL AND DENTAL SVCS' 'RADIOISOTOPE BONE SCAN' 'DX AMNIOCENTESIS'
#  'OT EXTRAOCULAR MUSC/ORB' 'BUNIONECTOMY/TOE DEFORM' 'DX PRCS ON EYE'
#  'INTRAOP CHOLANGIOGRAM' 'OT INTRAOCULAR THER PRC' 'MICRO EX (BACT SMEAR)'
#  'GLAUCOMA PROCEDURES' 'OT ORGAN TRANSPLANTATN' 'ARTHROSCOPY'
#  'BONE MARROW TRANSPLANT' 'RADIOISOTOPE PULM SCAN' 'INJ/LIG ESOPH VARICES'
#  'DIV OF JOINT CAPSULE' 'ARTERIAL BLOOD GASES' 'DES LES RETINA/CHOROID'
#  'DX PHYSICAL THERAPY' 'REPAIR RETINAL TEAR' 'ABORTION (TERM OF PREG)'
#  'LOWER GI X-RAY' 'VARI VEIN STRIP;LOW LMB' 'CORNEAL TRANSPLANT'
#  'MAMMOGRAPHY' 'TYMPANOPLASTY']
# ****************************************************************************************************
# apr_drg_code
# [753 141  53 203 199 139 134 463 251 424  41 460  47  45 760 138 565 844
#  243 723 750 381 754 566 204 140 560 540 254  54  52  58 190 136 893 563
#  756 420  44 240 244 247 280 241 194 751 775 201 144 930 133 131 249 759
#  226 722  55 758 843 173 842 225  23 589 690 890 242 380 221 720 545 757
#  841 773  82 224 892  73  20 175  21 440 740 137  70 531  40 362 283 135
#  461 207 755 774 422 113 383 861 282 111 425 710 253 351 640 228 513 197
#  317 466 694 812 721 626 263 385 223 206 220 541 581 279 633 262 519 114
#  347 816 308 446 143 544 130 301 663 341 561 349 284 811 421  48 115 465
#  198 229 530 660 951  26 245 468 314 952 813 110 950 912 248 302 200 711
#  639 312 770 340 281 384 724 636 580  57 227 344 316 382 313 305 542 342
#  512 482  24 171   5 246 174 121 191 196 252 346 315 404 192 177 661 532
#  170 662 169  43 815 650 776  98  50 614 364 514 621 501 441 752 205 625
#    4 361 791  46 180 343 691 320 447 193 681  51  42 264 167 462 443 634
#  483 142  80 405 518 860 772 442 161 222 480 623 500 484  56 310 309 260
#  261 444  49 862 176 165 162 321 163 166 850  22 423 120 304 303 546 564
#  401 680 403 481 363 445 910 651 692  97 894  89 517 160  93 631 611 693
#  622 591 588 593 612 607 602 609 583 613 863 132  90  95  92 608 603  91
#  911   6 511 510   3   2 630   1]
# ****************************************************************************************************
# apr_drg_description
# ['Bipolar disorders' 'Asthma' 'Seizure' 'Chest pain' 'Hypertension'
#  'Other pneumonia' 'Pulmonary embolism'
#  'Kidney & urinary tract infections' 'Abdominal pain'
#  'Other endocrine disorders' 'Nervous system malignancy' 'RENAL FAILURE'
#  'Transient ischemia' 'CVA & precerebral occlusion w infarct'
#  'Other mental health disorders' 'Bronchiolitis & RSV pneumonia'
#  'False labor' 'Partial thickness burns without skin graft'
#  'Other esophageal disorders' 'Viral illness' 'Schizophrenia'
#  'Major skin disorders' 'Depression except major depressive disorder'
#  'Other antepartum diagnoses' 'Syncope & collapse'
#  'Chronic obstructive pulmonary disease' 'Vaginal delivery'
#  'Cesarean delivery' 'Other digestive system diagnoses'
#  'Migraine & other headaches' 'Nontraumatic stupor & coma'
#  'Other disorders of nervous system' 'Acute myocardial infarction'
#  'Respiratory malignancy'
#  'HIV w multiple significant HIV related conditions' 'Preterm labor'
#  'Acute anxiety & delirium states' 'Diabetes' 'Intracranial hemorrhage'
#  'Digestive malignancy' 'Diverticulitis & diverticulosis'
#  'Intestinal obstruction' 'Alcoholic liver disease'
#  'Peptic ulcer & gastritis' 'Heart failure'
#  'Major depressive disorders & other/unspecified psychoses'
#  'Alcohol abuse & dependence' 'Cardiac arrhythmia & conduction disorders'
#  'Respiratory signs, symptoms & minor diagnoses'
#  'Multiple significant trauma w/o O.R. procedure' 'Respiratory Failure'
#  'Cystic fibrosis - pulmonary disease'
#  'Other gastroenteritis, nausa & vomiting' 'Eating disorders'
#  'Anal procedures' 'Fever' 'Head trauma w coma >1 hr or hemorrhage'
#  'Behavioral disorders'
#  'Extensive 3rd degree or full thickness burns w/o skin graft'
#  'OTHER VASCULAR PROCEDURES'
#  'Burns with skin graft except extensive 3rd degree burns' 'Appendectomy'
#  'Spinal procedures' 'Neonate bwt <500g or GA <24 weeks' 'Acute leukemia'
#  'HIV w multiple major HIV related conditions'
#  'Major esophageal disorders' 'Skin ulcers'
#  'Major small & large bowel procedures'
#  'Septicemia & disseminated infections' 'Ectopic pregnancy procedure'
#  'Organic mental health disturbances'
#  'Extensive 3rd degree burns w skin graft' 'Opioid abuse & dependence'
#  'Eye disorders except major infections' 'Peritoneal adhesiolysis'
#  'HIV w major HIV related condition' 'Eye procedures except orbit'
#  'Craniotomy for trauma' 'Percutaneous coronary intervention w/o AMI'
#  'Craniotomy except for trauma' 'Kidney transplant'
#  'Mental illness diagnosis w O.R. procedure'
#  'Major respiratory infections & inflammations' 'Orbital procedures'
#  'Female reproductive system infections' 'Spinal disorders & injuries'
#  'Mastectomy procedures' 'Other disorders of the liver'
#  'Major chest & respiratory trauma' 'Kidney & urinary tract malignancy'
#  'Other circulatory system diagnoses'
#  'Adjustment disorders & neuroses except depressive diagnoses'
#  'Cocaine abuse & dependence'
#  'Hypovolemia & related electrolyte disorders'
#  'Infections of upper respiratory tract'
#  'Cellulitis & other skin infections'
#  'Signs, symptoms & other factors influencing health status'
#  'Disorders of pancreas except malignancy'
#  'Vertigo & other labyrinth disorders'
#  'Electrolyte disorders except hypovolemia related'
#  'Infectious & parasitic diseases including HIV w O.R. procedure'
#  'Other & unspecified gastrointestinal hemorrhage'
#  'Other musculoskeletal system & connective tissue diagnoses'
#  'Neonate birthwt >2499g, normal newborn or neonate w other problem'
#  'Inguinal, femoral & umbilical hernia procedures'
#  'Uterine & adnexa procedures for non-malignancy except leiomyoma'
#  'Peripheral & other vascular disorders'
#  'Tendon, muscle & other soft tissue procedures'
#  'Malfunction, reaction, complic of genitourinary device or proc'
#  'Lymphatic & other malignancies & neoplasms of uncertain behavior'
#  'Poisoning of medicinal agents'
#  'Post-operative, post-traumatic, other device infections'
#  'Neonate bwt 2000-2499g, normal newborn or neonate w other problem'
#  'Laparoscopic cholecystectomy'
#  'Other skin, subcutaneous tissue & breast disorders'
#  'Other small & large bowel procedures'
#  'Malfunction,reaction,complication of cardiac/vasc device or procedure'
#  'Major stomach, esophageal & duodenal procedures'
#  'Vaginal delivery w sterilization &/or D&C'
#  'Neonate, transferred < 5 days old, born here'
#  'Hepatic coma & other major acute liver disorders'
#  'Neonate birthwt >2499g w major anomaly'
#  'Cholecystectomy except laparoscopic'
#  'Uterine & adnexa procedures for leiomyoma'
#  'Dental & oral diseases & injuries'
#  'Other back & neck disorders, fractures & injuries'
#  'Toxic effects of non-medicinal substances'
#  'Hip and femur fracture repair' 'Urethral & transurethral procedures'
#  'Other respiratory diagnoses except signs, symptoms & minor diagnoses'
#  'D&C, aspiration curettage or hysterotomy for obstetric diagnoses'
#  'Respiratory system diagnosis w ventilator support 96+ hours'
#  'Hip joint replacement'
#  'Other anemia & disorders of blood & blood-forming organs'
#  'Fracture of pelvis or dislocation of hip'
#  'Postpartum & post abortion diagnoses w/o procedure'
#  'Malfunction, reaction, complic of orthopedic device or procedure'
#  'Disorders of gallbladder & biliary tract' 'Allergic reactions'
#  'Malnutrition, failure to thrive & other nutritional disorders'
#  'Peripheral, cranial & autonomic nerve disorders'
#  'Other ear, nose, mouth,throat & cranial/facial diagnoses'
#  'Urinary stones & acquired upper urinary tract obstruction'
#  'Angina pectoris & coronary atherosclerosis'
#  'Other digestive system & abdominal procedures'
#  'Female reproductive system malignancy'
#  'Major hematologic/immunologic diag exc sickle cell crisis & coagul'
#  'Moderately extensive procedure unrelated to principal diagnosis'
#  'Other nervous system & related procedures' 'Inflammatory bowel disease'
#  'Other kidney & urinary tract diagnoses, signs & symptoms'
#  'Foot & toe procedures'
#  'Nonextensive procedure unrelated to principal diagnosis'
#  'Other complications of treatment'
#  'Ear, nose, mouth, throat, cranial/facial malignancies'
#  'Extensive procedure unrelated to principal diagnosis'
#  'Musculoskeletal & other procedures for multiple significant trauma'
#  'Major gastrointestinal & peritoneal infections' 'Knee joint replacement'
#  'Cardiac structural & valvular disorders'
#  'Post-op, post-trauma, other device infections w O.R. procedure'
#  'Neonate birthwt >2499g w other significant condition'
#  'Skin graft, except hand, for musculoskeletal & connective tissue diagnoses'
#  'Drug & alcohol abuse or dependence, left against medical advice'
#  'Fracture of femur' 'Malignancy of hepatobiliary system & pancreas'
#  'Contusion, open wound & other trauma to skin & subcutaneous tissue'
#  'Other infectious & parasitic diseases'
#  'Neonate birthwt >2499g w congenital/perinatal infection'
#  'Neonate, transferred <5 days old, not born here'
#  'Concussion, closed skull Fx nos,uncomplicated intracranial injury, coma < 1 hr or no coma'
#  'Hernia procedures except inguinal, femoral & umbilical'
#  'Osteomyelitis, septic arthritis & other musculoskeletal infections'
#  'Hand & wrist procedures' 'Malignant breast disorders'
#  'Knee & lower leg procedures except foot'
#  'Amputation of lower limb except toes'
#  'Vaginal delivery w complicating procedures exc sterilization &/or D&C'
#  'Fractures & dislocations except femur, pelvis & back'
#  'Uterine & adnexa procedures for non-ovarian & non-adnexal malig'
#  'Transurethral prostatectomy' 'Extracranial vascular procedures'
#  'Perm cardiac pacemaker implant w/o AMI, heart failure or shock'
#  'Tracheostomy w MV 96+ hours w/o extensive procedure'
#  'Gastrointestinal vascular insufficiency'
#  'Percutaneous coronary intervention w AMI'
#  'Other respiratory & chest procedures'
#  'Cardiac catheterization for coronary artery disease'
#  'Cardiac arrest and shock'
#  'Malfunction, reaction & complication of GI device or procedure'
#  'Connective tissue disorders'
#  'Shoulder, upper arm & forearm procedures except joint replacement'
#  'Thyroid, parathyroid & thyroglossal procedures'
#  'Cardiac catheterization for other non-coronary conditions'
#  'Cardiac pacemaker & defibrillator revision except device replacement'
#  'Coagulation & platelet disorders'
#  'Menstrual & other female reproductive system disorders'
#  'Permanent cardiac pacemaker implant w AMI, heart failure or shock'
#  'Sickle cell anemia crisis' 'Major abdominal vascular procedures'
#  'Multiple sclerosis & other demyelinating diseases'
#  'Other injury, poisoning & toxic effect diagnoses' 'Splenectomy'
#  'Other drug abuse & dependence'
#  'Other ear, nose, mouth & throat procedures'
#  'Non-bacterial infections of nervous system exc viral meningitis'
#  'Neonate bwt 1500-1999g w or w/o other significant condition'
#  'Other skin, subcutaneous tissue & related procedures'
#  'Female reproductive system reconstructive procedures'
#  'Neonate bwt 2000-2499g w major anomaly'
#  'Male reproductive system diagnoses except malignancy'
#  'Major bladder procedures' 'Disorders of personality & impulse control'
#  'Cardiomyopathy' 'Neonate bwt 2000-2499g w other significant condition'
#  'Tracheostomy w MV 96+ hours w extensive procedure or ECMO'
#  'Skin graft for skin & subcutaneous tissue diagnoses'
#  'O.R. procedure for other complications of treatment'
#  'Nonspecific CVA & precerebral occlusion w/o infarct'
#  'Other circulatory system procedures'
#  'Musculoskeletal malignancy & pathol fracture d/t muscskel malig'
#  'Lymphoma, myeloma & non-acute leukemia'
#  'Other musculoskeletal system & connective tissue procedures'
#  'Other kidney, urinary tract & related procedures'
#  'Acute & subacute endocarditis'
#  'Other O.R. procedures for lymphatic/hematopoietic/other neoplasms'
#  'Viral meningitis'
#  'Degenerative nervous system disorders exc mult sclerosis'
#  'Other hepatobiliary, pancreas & abdominal procedures'
#  'Other cardiothoracic & thoracic vascular procedures'
#  'Nephritis & nephrosis'
#  'Kidney & urinary tract procedures for nonmalignancy'
#  'Neonate, birthwt >2499g w resp dist synd/oth maj resp cond'
#  'Testes & scrotal procedures' 'Interstitial & alveolar lung diseases'
#  'Acute major eye infections'
#  'Other procedures for endocrine, nutritional & metabolic disorders'
#  'Other female reproductive system & related procedures' 'Rehabilitation'
#  'Alcohol & drug dependence w rehab or rehab/detox therapy'
#  'Kidney & urinary tract procedures for malignancy'
#  'Cardiac defibrillator & heart assist implant'
#  'Other stomach, esophageal & duodenal procedures'
#  'Major male pelvic procedures'
#  'Neonate bwt 2000-2499g w congenital/perinatal infection'
#  'Malignancy, male reproductive system'
#  'Other male reproductive system & related procedures'
#  'Brain contusion/laceration & complicated skull Fx, coma < 1 hr or no coma'
#  'Intervertebral disc excision & decompression'
#  'Other significant hip and femur surgery'
#  'Major pancreas, liver & shunt procedures'
#  'Major biliary tract procedures'
#  'Renal dialysis access device procedure only'
#  'Bacterial & tuberculous infections of nervous system'
#  'Other aftercare & convalescence'
#  'Cardiac pacemaker & defibrillator device replacement'
#  'Coronary bypass w AMI or complex PDX'
#  'Cardiac valve procedures w AMI or complex PDX'
#  'Cervical spinal fusion & other back/neck proc exc disc excis/decomp'
#  'Cardiac valve procedures w/o AMI or complex PDX'
#  'Coronary bypass w/o AMI or complex PDX'
#  'Procedure w diag of rehab, aftercare or oth contact w health service'
#  'Ventricular shunt procedures' 'Inborn errors of metabolism'
#  'Major respiratory & chest procedures'
#  'Dorsal & lumbar fusion proc except for curvature of back'
#  'Dorsal & lumbar fusion proc for curvature of back'
#  'Other O.R. proc for obstetric diagnoses except delivery diagnoses'
#  'Abortion w/o D&C, aspiration curettage or hysterotomy'
#  'Pituitary & adrenal procedures'
#  'Major O.R. procedures for lymphatic/hematopoietic/other neoplasms'
#  'Procedures for obesity' 'Penis procedures'
#  'Breast procedures except mastectomy' 'Other bladder procedures'
#  'Craniotomy for multiple significant trauma'
#  'Other procedures of blood & blood-forming organs' 'Radiotherapy'
#  'Tonsil & adenoid procedures'
#  'HIV w one signif HIV cond or w/o signif related cond'
#  'Major cranial/facial bone procedures'
#  'Dilation & curettage for non-obstetric diagnoses'
#  'Major cardiothoracic repair of heart anomaly'
#  'Sinus & mastoid procedures'
#  'Neonate birthwt >2499g w other major procedure'
#  'Neonate birthwt 1500-1999g w major anomaly' 'CHEMOTHERAPY'
#  'Neonate bwt 2000-2499g w resp dist synd/oth maj resp cond'
#  'Neonate birthwt 500-749g w/o major procedure'
#  'Neonate bwt <1500g w major procedure'
#  'Neonate birthwt 750-999g w/o major procedure'
#  'Neonate bwt 1500-1999g w resp dist synd/oth maj resp cond'
#  'Neonate bwt 1250-1499g w resp dist synd/oth maj resp or maj anom'
#  'Neonate bwt 1000-1249g w resp dist synd/oth maj resp or maj anom'
#  'Neonate bwt 1500-2499g w major procedure' 'Neonate w ECMO'
#  'Neonate birthwt 1500-1999g w congenital/perinatal infection'
#  'Neonatal aftercare'
#  'BPD & oth chronic respiratory diseases arising in perinatal period'
#  'Major larynx & trachea procedures' 'Cleft lip & palate repair'
#  'Facial bone procedures except major cranial/facial bone procedures'
#  'Neonate bwt 1250-1499g w or w/o other significant condition'
#  'Neonate birthwt 1000-1249g w or w/o other significant condition'
#  'Other major head & neck procedures'
#  'Extensive abdominal/thoracic procedures for mult significant trauma'
#  'Pancreas transplant'
#  'Uterine & adnexa procedures for ovarian & adnexal malignancy'
#  'Pelvic evisceration, radical hysterectomy & other radical GYN procs'
#  'Bone marrow transplant' 'Heart &/or lung transplant'
#  'Neonate birthwt >2499g w major cardiovascular procedure'
#  'Liver transplant &/or intestinal transplant']
# ****************************************************************************************************
# apr_mdc_code
# [19  4  1  5 11  6 10 14 22 18  9 24  7 20 25 15 17  2 13  3 23  8 21 16
#  12]
# ****************************************************************************************************
# apr_mdc_description
# ['Mental Diseases and Disorders'
#  'Diseases and Disorders of the Respiratory System'
#  'Diseases and Disorders of the Nervous System'
#  'Diseases and Disorders of the Circulatory System'
#  'Diseases and Disorders of the Kidney and Urinary Tract'
#  'Diseases and Disorders of the Digestive System'
#  'Endocrine, Nutritional and Metabolic Diseases and Disorders'
#  'Pregnancy, Childbirth and the Puerperium' 'Burns'
#  'Infectious and Parasitic Diseases, Systemic or Unspecified Sites'
#  'Diseases and Disorders of the Skin, Subcutaneous Tissue and Breast'
#  'Human Immunodeficiency Virus Infections'
#  'Diseases and Disorders of the Hepatobiliary System and Pancreas'
#  'Alcohol/Drug Use and Alcohol/Drug Induced Organic Mental Disorders'
#  'Multiple Significant Trauma'
#  'Newborns and Other Neonates with Conditions Originating in the Perinatal Period'
#  'Lymphatic, Hematopoietic, Other Malignancies, Chemotherapy and Radiotherapy'
#  'Diseases and Disorders of the Eye'
#  'Diseases and Disorders of the Female Reproductive System'
#  'Ear, Nose, Mouth, Throat and Craniofacial Diseases and Disorders'
#  'Rehabilitation, Aftercare, Other Factors Influencing Health Status and Other Health Service Contacts'
#  'Diseases and Disorders of the Musculoskeletal System and Conn Tissue'
#  'Poisonings, Toxic Effects, Other Injuries and Other Complications of Treatment'
#  'Diseases and Disorders of Blood, Blood Forming Organs and Immunological Disorders'
#  'Diseases and Disorders of the Male Reproductive System']
# ****************************************************************************************************
# apr_severity_of_illness_code
# [1 2 3 4]
# ****************************************************************************************************
# apr_severity_of_illness_description
# ['Minor' 'Moderate' 'Major' 'Extreme']
# ****************************************************************************************************
# apr_risk_of_mortality
# ['Minor' 'Moderate' 'Major' 'Extreme']
# ****************************************************************************************************
# apr_medical_surgical_description
# ['Medical' 'Surgical']
# ****************************************************************************************************
# payment_typology_1
# ['Medicaid' 'Medicare' 'Private Health Insurance' 'Blue Cross/Blue Shield'
#  'Self-Pay' 'Federal/State/Local/VA' 'Miscellaneous/Other'
#  'Managed Care, Unspecified' 'Unknown' 'Department of Corrections']
# ****************************************************************************************************
# attending_provider_license_number
# [267162. 275408. 271326. ... 257839. 261578. 281954.]
# ****************************************************************************************************
# birth_weight
# [   0 4200 3400 3300 2400 2800 3500 3200 2600 3600 4300 4000 3800 3900
#  3100 2300 3700 2900 4500 4400 3000 2700 2500 2100 2200 1700 4100 4700
#  2000 4600 5000 1800 1900 1400 1500 1200 1000 5500 5200 1600 5100 5600
#  4900 9100 6100 4800 9300 9900 1300 9500 7000 8400 8000 7100 6000 7800
#  8300 8600 9400 9200 9700 9600 6400 7700 8700 7900 1100 9800 7400 5400
#  5300 8800 6500 5900 6900 7300 7500 5700 7200 6300 6600 8500 8900 9000
#  7600 6700 6200 8100 5800 6800 8200]
# ****************************************************************************************************
# abortion_edit_indicator
# ['N']
# ****************************************************************************************************
# emergency_department_indicator
# ['Y' 'N']
# ****************************************************************************************************
# total_charges
# ['$5620.00' '$7404.18' '$7931.28' ... '$177142.00' '$17567.20'
#  '$109189.00']
# ****************************************************************************************************
# total_costs
# ['$4561.28' '$6933.94' '$7154.85' ... '$4025.68' '$6637.09' '$1862.39']
# ****************************************************************************************************

# %%
# checking features value counts.
for i in list(df.columns):
    print(i)
    print(df[i].value_counts())
    print("*"*100)
# Out:
# health_service_area
# New York City     1090826
# Long Island        339240
# Hudson Valley      245917
# Capital/Adiron     167322
# Western NY         163893
# Central NY         158296
# Finger Lakes       146558
# Southern Tier       30169
# Name: health_service_area, dtype: int64
# ****************************************************************************************************
# hospital_county
# Manhattan      399693
# Kings          248927
# Queens         197173
# Bronx          188124
# Nassau         181142
# Suffolk        158098
# Erie           120556
# Westchester    119375
# Monroe         105154
# Onondaga        78374
# Albany          65717
# Richmond        56909
# Orange          39500
# Dutchess        32594
# Rockland        31940
# Oneida          29902
# Broome          28525
# Schenectady     22325
# Niagara         17152
# Warren          14090
# Chemung         13845
# Otsego          12265
# Rensselaer      11957
# Ontario         11950
# Ulster          11359
# St Lawrence     11106
# Jefferson       10823
# Chautauqua      10489
# Clinton          9816
# Saratoga         9237
# Tompkins         7246
# Montgomery       6923
# Putnam           6795
# Steuben          6306
# Columbia         5847
# Cattaraugus      5790
# Wayne            5657
# Cayuga           5339
# Oswego           4714
# Madison          4709
# Franklin         4596
# Sullivan         4354
# Genesee          4292
# Cortland         3930
# Fulton           2900
# Livingston       2296
# Wyoming          2265
# Allegany         2117
# Chenango         1644
# Lewis            1417
# Orleans          1232
# Yates             747
# Herkimer          736
# Delaware          693
# Schuyler          603
# Essex             479
# Schoharie         477
# Name: hospital_county, dtype: int64
# ****************************************************************************************************
# operating_certificate_number
# 7002054.0    117268
# 7000006.0     89140
# 7002024.0     63949
# 7003004.0     62330
# 1401014.0     54425
#               ...
# 226700.0         64
# 5263700.0        52
# 2701006.0        29
# 632000.0         14
# 1302000.0         5
# Name: operating_certificate_number, Length: 179, dtype: int64
# ****************************************************************************************************
# facility_id
# 1456.0    55733
# 541.0     47705
# 1464.0    47449
# 1458.0    42748
# 1169.0    42717
#           ...
# 37.0         64
# 968.0        52
# 414.0        29
# 111.0        14
# 2.0          10
# Name: facility_id, Length: 213, dtype: int64
# ****************************************************************************************************
# facility_name
# Mount Sinai Hospital                                              55733
# North Shore University Hospital                                   47705
# New York Presbyterian Hospital - Columbia Presbyterian Center     47449
# New York Presbyterian Hospital - New York Weill Cornell Center    42748
# Montefiore Medical Center - Henry & Lucy Moses Div                42717
#                                                                   ...
# Cuba Memorial Hospital Inc                                           64
# Catskill Regional Medical Center - G. Hermann Site                   52
# Monroe Community Hospital                                            29
# Westfield Memorial Hospital Inc                                      14
# Albany Medical Center - South Clinical Campus                        10
# Name: facility_name, Length: 214, dtype: int64
# ****************************************************************************************************
# age_group
# 50 to 69       644774
# 70 or Older    643124
# 30 to 49       456448
# 0 to 17        352050
# 18 to 29       245825
# Name: age_group, dtype: int64
# ****************************************************************************************************
# zip_code__3_digits
# 112    313540
# 104    224984
# 117    182027
# 100    170124
# 113    121511
# 114     91275
# 115     88662
# OOS     67141
# 142     66140
# 103     62228
# 105     61846
# 109     59262
# 146     56204
# 125     46284
# 140     43809
# 130     40062
# 120     34926
# 119     34085
# 145     31454
# 107     30946
# 121     30480
# 132     29326
# 144     29246
# 110     26779
# 136     26071
# 148     25026
# 128     24437
# 134     21468
# 141     21115
# 124     20468
# 111     20023
# 131     18518
# 123     18445
# 116     18444
# 122     17873
# 147     17279
# 133     16187
# 129     15133
# 137     14450
# 138     13706
# 127     12122
# 126     10865
# 135     10669
# 143     10160
# 108      9388
# 139      9104
# 106      9004
# 118      7932
# 149      6488
# 101      5505
# Name: zip_code__3_digits, dtype: int64
# ****************************************************************************************************
# gender
# F    1303589
# M    1038593
# U         39
# Name: gender, dtype: int64
# ****************************************************************************************************
# race
# White                     1333050
# Other Race                 543104
# Black/African American     443817
# Multi-racial                22250
# Name: race, dtype: int64
# ****************************************************************************************************
# ethnicity
# Not Span/Hispanic    1950947
# Spanish/Hispanic      277819
# Unknown               104801
# Multi-ethnic            8654
# Name: ethnicity, dtype: int64
# ****************************************************************************************************
# length_of_stay
# 2      542347
# 3      424065
# 1      337195
# 4      247358
# 5      160530
#         ...
# 111        41
# 119        41
# 115        37
# 116        31
# 108        26
# Name: length_of_stay, Length: 120, dtype: int64
# ****************************************************************************************************
# type_of_admission
# Emergency        1485353
# Elective          446428
# Newborn           226682
# Urgent            176196
# Trauma              6392
# Not Available       1170
# Name: type_of_admission, dtype: int64
# ****************************************************************************************************
# patient_disposition
# Home or Self Care                        1568050
# Home w/ Home Health Services              304155
# Skilled Nursing Home                      223941
# Expired                                    50958
# Left Against Medical Advice                46998
# Inpatient Rehabilitation Facility          44504
# Short-term Hospital                        40468
# Hospice - Medical Facility                 12656
# Psychiatric Hospital or Unit of Hosp       12072
# Hospice - Home                             10724
# Another Type Not Listed                     8351
# Facility w/ Custodial/Supportive Care       6678
# Court/Law Enforcement                       3882
# Medicare Cert Long Term Care Hospital       3445
# Cancer Center or Children's Hospital        2906
# Hosp Basd Medicare Approved Swing Bed       1547
# Federal Health Care Facility                 621
# Critical Access Hospital                     153
# Medicaid Cert Nursing Facility               112
# Name: patient_disposition, dtype: int64
# ****************************************************************************************************
# discharge_year
# 2015    2342221
# Name: discharge_year, dtype: int64
# ****************************************************************************************************
# ccs_diagnosis_code
# 218    226394
# 2      108662
# 203     63432
# 108     58734
# 657     56914
#         ...
# 178        51
# 86         33
# 206        28
# 176        23
# 174         8
# Name: ccs_diagnosis_code, Length: 263, dtype: int64
# ****************************************************************************************************
# ccs_diagnosis_description
# Liveborn                                     226394
# Septicemia (except in labor)                 108662
# Osteoarthritis                                63432
# Congestive heart failure; nonhypertensive     58734
# Mood disorders                                56914
#                                               ...
# Induced abortion                                 51
# Cataract                                         33
# Osteoporosis                                     28
# Contraceptive and procreative management         23
# Female infertility                                8
# Name: ccs_diagnosis_description, Length: 263, dtype: int64
# ****************************************************************************************************
# ccs_procedure_code
# 0      609688
# 231    175270
# 137     83291
# 228     80961
# 134     74687
#         ...
# 126        13
# 22         13
# 182         9
# 46          8
# 68          7
# Name: ccs_procedure_code, Length: 232, dtype: int64
# ****************************************************************************************************
# ccs_procedure_description
# NO PROC                    609688
# OTHER THERAPEUTIC PRCS     175270
# OT PRCS TO ASSIST DELIV     83291
# PROPHYLACTIC VAC/INOCUL     80961
# CESAREAN SECTION            74687
#                             ...
# ABORTION (TERM OF PREG)        13
# TYMPANOPLASTY                  13
# MAMMOGRAPHY                     9
# CORONARY THROMBOLYSIS           8
# INJ/LIG ESOPH VARICES           7
# Name: ccs_procedure_description, Length: 232, dtype: int64
# ****************************************************************************************************
# apr_drg_code
# 640    197816
# 560    146636
# 720     94929
# 540     75940
# 194     56350
#         ...
# 564        91
# 583        53
# 841        43
# 580        35
# 6          34
# Name: apr_drg_code, Length: 314, dtype: int64
# ****************************************************************************************************
# apr_drg_description
# Neonate birthwt >2499g, normal newborn or neonate w other problem    197816
# Vaginal delivery                                                     146636
# Septicemia & disseminated infections                                  94929
# Cesarean delivery                                                     75940
# Heart failure                                                         56350
#                                                                       ...
# Abortion w/o D&C, aspiration curettage or hysterotomy                    91
# Neonate w ECMO                                                           53
# Extensive 3rd degree burns w skin graft                                  43
# Neonate, transferred <5 days old, not born here                          35
# Pancreas transplant                                                      34
# Name: apr_drg_description, Length: 314, dtype: int64
# ****************************************************************************************************
# apr_mdc_code
# 5     289419
# 14    250907
# 15    231451
# 8     204551
# 6     197548
# 4     196391
# 1     141801
# 18    130892
# 19    116146
# 11    102194
# 20     75034
# 10     73073
# 7      63047
# 9      60799
# 23     40273
# 16     35131
# 3      30164
# 21     27873
# 13     26415
# 17     21674
# 12     10593
# 24      7202
# 25      3920
# 2       3625
# 22      2098
# Name: apr_mdc_code, dtype: int64
# ****************************************************************************************************
# apr_mdc_description
# Diseases and Disorders of the Circulatory System                                                        289419
# Pregnancy, Childbirth and the Puerperium                                                                250907
# Newborns and Other Neonates with Conditions Originating in the Perinatal Period                         231451
# Diseases and Disorders of the Musculoskeletal System and Conn Tissue                                    204551
# Diseases and Disorders of the Digestive System                                                          197548
# Diseases and Disorders of the Respiratory System                                                        196391
# Diseases and Disorders of the Nervous System                                                            141801
# Infectious and Parasitic Diseases, Systemic or Unspecified Sites                                        130892
# Mental Diseases and Disorders                                                                           116146
# Diseases and Disorders of the Kidney and Urinary Tract                                                  102194
# Alcohol/Drug Use and Alcohol/Drug Induced Organic Mental Disorders                                       75034
# Endocrine, Nutritional and Metabolic Diseases and Disorders                                              73073
# Diseases and Disorders of the Hepatobiliary System and Pancreas                                          63047
# Diseases and Disorders of the Skin, Subcutaneous Tissue and Breast                                       60799
# Rehabilitation, Aftercare, Other Factors Influencing Health Status and Other Health Service Contacts     40273
# Diseases and Disorders of Blood, Blood Forming Organs and Immunological Disorders                        35131
# Ear, Nose, Mouth, Throat and Craniofacial Diseases and Disorders                                         30164
# Poisonings, Toxic Effects, Other Injuries and Other Complications of Treatment                           27873
# Diseases and Disorders of the Female Reproductive System                                                 26415
# Lymphatic, Hematopoietic, Other Malignancies, Chemotherapy and Radiotherapy                              21674
# Diseases and Disorders of the Male Reproductive System                                                   10593
# Human Immunodeficiency Virus Infections                                                                   7202
# Multiple Significant Trauma                                                                               3920
# Diseases and Disorders of the Eye                                                                         3625
# Burns                                                                                                     2098
# Name: apr_mdc_description, dtype: int64
# ****************************************************************************************************
# apr_severity_of_illness_code
# 2    895521
# 1    783503
# 3    516571
# 4    146626
# Name: apr_severity_of_illness_code, dtype: int64
# ****************************************************************************************************
# apr_severity_of_illness_description
# Moderate    895521
# Minor       783503
# Major       516571
# Extreme     146626
# Name: apr_severity_of_illness_description, dtype: int64
# ****************************************************************************************************
# apr_risk_of_mortality
# Minor       1385860
# Moderate     499685
# Major        335013
# Extreme      121663
# Name: apr_risk_of_mortality, dtype: int64
# ****************************************************************************************************
# apr_medical_surgical_description
# Medical     1777074
# Surgical     565147
# Name: apr_medical_surgical_description, dtype: int64
# ****************************************************************************************************
# payment_typology_1
# Medicare                     875810
# Medicaid                     715311
# Private Health Insurance     333320
# Blue Cross/Blue Shield       274930
# Self-Pay                      67698
# Miscellaneous/Other           28965
# Managed Care, Unspecified     22969
# Federal/State/Local/VA        12419
# Unknown                        6270
# Department of Corrections      4529
# Name: payment_typology_1, dtype: int64
# ****************************************************************************************************
# attending_provider_license_number
# 149952.0      3715
# 260380.0      3470
# 153130.0      2851
# 175020.0      2821
# 227307.0      2746
#               ...
# 272364.0         1
# 211254.0         1
# 240509.0         1
# 90070836.0       1
# 277806.0         1
# Name: attending_provider_license_number, Length: 27085, dtype: int64
# ****************************************************************************************************
# birth_weight
# 0       2107630
# 3300      19400
# 3200      19324
# 3400      18431
# 3100      17684
#          ...
# 5900         21
# 7700         20
# 8200         19
# 9200         18
# 8300         17
# Name: birth_weight, Length: 91, dtype: int64
# ****************************************************************************************************
# abortion_edit_indicator
# N    2342221
# Name: abortion_edit_indicator, dtype: int64
# ****************************************************************************************************
# emergency_department_indicator
# Y    1366490
# N     975731
# Name: emergency_department_indicator, dtype: int64
# ****************************************************************************************************
# total_charges
# $9973.90      1325
# $8375.20       929
# $4285.44       814
# $4376.42       644
# $10575.90      616
#               ...
# $20055.23        1
# $15700.40        1
# $24984.90        1
# $32199.70        1
# $109189.00       1
# Name: total_charges, Length: 1784798, dtype: int64
# ****************************************************************************************************
# total_costs
# $1046.14     1324
# $1712.33      930
# $3061.21      815
# $4216.68      646
# $1146.07      602
#              ...
# $14179.73       1
# $74364.83       1
# $35281.75       1
# $10459.79       1
# $1862.39        1
# Name: total_costs, Length: 1526541, dtype: int64
# ****************************************************************************************************

# %% [markdown]
# From the above info, unique, and value counts we found that:
# 1. zip_code__3_digits feature have strange value 'OOS' repeated 67135 times which refer to Out of State zip codes we can replace it with 005 to indicate out of state. Also, changing dtype to numeric.
# 2. gender feature have strange value 'U' repeated 39 times we are going to drop it.
# 3. length_of_stay feature have '120 +' value need to be modified, by adding new feature for over_120_stay, then remove + sine. also dtype need to be change to numerical.
# 4. discharge_year feature have only 2015 value. it will not be useful we are going to drop it.
# 5. attending_provider_license_number feature it is not useful and we are going to drop it.
# 6. abortion_edit_indicator feature have only 'N' value. it will not be useful we are going to drop it.
# 7. total_charges feature have Dollar signe. need to be removed and replace dtype.
# 8. total_costs feature have Dollar signe. need to be removed and replace dtype.

# %%
# starting with zip_code__3_digits feature replacing 'OOS' values to '005' and fixing dtype.
df['zip_code__3_digits'] = df['zip_code__3_digits'].apply(lambda x: str(x).replace('OOS','005'))
df['zip_code__3_digits'] = pd.to_numeric(df['zip_code__3_digits'])
df['zip_code__3_digits'].value_counts()
# Out:
# 112    313540
# 104    224984
# 117    182027
# 100    170124
# 113    121511
# 114     91275
# 115     88662
# 5       67141
# 142     66140
# 103     62228
# 105     61846
# 109     59262
# 146     56204
# 125     46284
# 140     43809
# 130     40062
# 120     34926
# 119     34085
# 145     31454
# 107     30946
# 121     30480
# 132     29326
# 144     29246
# 110     26779
# 136     26071
# 148     25026
# 128     24437
# 134     21468
# 141     21115
# 124     20468
# 111     20023
# 131     18518
# 123     18445
# 116     18444
# 122     17873
# 147     17279
# 133     16187
# 129     15133
# 137     14450
# 138     13706
# 127     12122
# 126     10865
# 135     10669
# 143     10160
# 108      9388
# 139      9104
# 106      9004
# 118      7932
# 149      6488
# 101      5505
# Name: zip_code__3_digits, dtype: int64

# %%
# droping 'U' values from gender feature
df = df.loc[df.gender != 'U']

# %%
df.gender.value_counts()
# Out:
# F    1303589
# M    1038593
# Name: gender, dtype: int64

# %%
# finding out how many values in the data have '120 +' values
df[df['length_of_stay']== '120 +']['length_of_stay'].count()
# Out:
# 1857

# %%
# function to conver 120 + length of stay to new columns over_120_stay contain (0=false, 1=true)
def over_120_stay(x):
    if x == '120 +':
        return 1
    else:
        return 0
    
df['over_120_stay'] = df['length_of_stay'].apply(over_120_stay)
df['over_120_stay'].value_counts()
# Out:
# 0    2340325
# 1       1857
# Name: over_120_stay, dtype: int64

# %%
# length_of_stay feature have '120 +' value be modified by remove + sine. also dtype need to be change to numerical.
df['length_of_stay'] = df['length_of_stay'].replace('120 +','120')

# %%
df['length_of_stay'].unique()
# Out:
# array(['5', '8', '4', '3', '2', '9', '1', '59', '10', '17', '35', '15',
#        '12', '7', '98', '26', '6', '46', '32', '16', '21', '22', '13',
#        '77', '14', '58', '28', '11', '18', '19', '29', '27', '42', '24',
#        '23', '31', '37', '57', '25', '20', '30', '63', '43', '49', '45',
#        '102', '56', '33', '40', '34', '55', '100', '47', '38', '61', '53',
#        '117', '62', '120', '80', '48', '70', '44', '51', '41', '64', '50',
#        '36', '107', '68', '74', '39', '87', '83', '54', '105', '81',
#        '112', '76', '91', '86', '66', '72', '94', '93', '67', '69', '73',
#        '119', '115', '75', '97', '92', '95', '60', '65', '82', '79', '71',
#        '84', '109', '103', '118', '52', '101', '85', '110', '106', '88',
#        '111', '104', '89', '78', '116', '90', '113', '108', '114', '96',
#        '99'], dtype=object)

# %%
# changing data type to numerical
df['length_of_stay']=pd.to_numeric(df['length_of_stay'])

# %%
# droping unecessery features ['discharge_year','attending_provider_license_number','abortion_edit_indicator']
df.drop(['discharge_year','attending_provider_license_number','abortion_edit_indicator'],axis=1,inplace=True)

# %%
# replacing Dollar signs in total_charges & total_costs features and changing there dtype from object to numerical
df['total_costs'] = df['total_costs'].str.replace('$','')
df['total_charges'] = df['total_charges'].str.replace('$','')

# changing data type from object to numerical
df['total_costs'] = pd.to_numeric(df['total_costs'])
df['total_charges'] = pd.to_numeric(df['total_charges'])

# %%
df['total_costs']
# Out:
# 0          4561.28
# 1          6933.94
# 2          7154.85
# 3          4584.11
# 4          4361.74
#             ...
# 2346755    6637.09
# 2346756    3236.18
# 2346757    1862.39
# 2346758    2744.13
# 2346759    2128.89
# Name: total_costs, Length: 2342182, dtype: float64

# %%
df.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2342182 entries, 0 to 2346759
# Data columns (total 31 columns):
#  #   Column                               Non-Null Count    Dtype
# ---  ------                               --------------    -----
#  0   health_service_area                  2342182 non-null  object
#  1   hospital_county                      2342182 non-null  object
#  2   operating_certificate_number         2342182 non-null  float64
#  3   facility_id                          2342182 non-null  float64
#  4   facility_name                        2342182 non-null  object
#  5   age_group                            2342182 non-null  object
#  6   zip_code__3_digits                   2342182 non-null  int64
#  7   gender                               2342182 non-null  object
#  8   race                                 2342182 non-null  object
#  9   ethnicity                            2342182 non-null  object
#  10  length_of_stay                       2342182 non-null  int64
#  11  type_of_admission                    2342182 non-null  object
#  12  patient_disposition                  2342182 non-null  object
#  13  ccs_diagnosis_code                   2342182 non-null  int64
#  14  ccs_diagnosis_description            2342182 non-null  object
#  15  ccs_procedure_code                   2342182 non-null  int64
#  16  ccs_procedure_description            2342182 non-null  object
#  17  apr_drg_code                         2342182 non-null  int64
#  18  apr_drg_description                  2342182 non-null  object
#  19  apr_mdc_code                         2342182 non-null  int64
#  20  apr_mdc_description                  2342182 non-null  object
#  21  apr_severity_of_illness_code         2342182 non-null  int64
#  22  apr_severity_of_illness_description  2342182 non-null  object
#  23  apr_risk_of_mortality                2342182 non-null  object
#  24  apr_medical_surgical_description     2342182 non-null  object
#  25  payment_typology_1                   2342182 non-null  object
#  26  birth_weight                         2342182 non-null  int64
#  27  emergency_department_indicator       2342182 non-null  object
#  28  total_charges                        2342182 non-null  float64
#  29  total_costs                          2342182 non-null  float64
#  30  over_120_stay                        2342182 non-null  int64
# dtypes: float64(4), int64(9), object(18)
# memory usage: 571.8+ MB

# %%
#checking for duplication in data 
df.duplicated().sum()
# Out:
# 10598

# %%
# Drop duplicates and reset the index
df = df.drop_duplicates().reset_index(drop=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# saving file after cleaning process.
df.to_csv('../data/processed/cleaned_data.csv',index=False)

# %% [markdown]
# Data Cleaning & prepration Summery:
# * Modifying columns names to be more suitable.
# ---
# * As the data contains 2.35 million rows and 37 columns then For any columns that have more than 20% missing values we drop the columns. Affected columns as follows:
# 1. payment_typology_2 by                     32.490264 %
# 2. payment_typology_3 by                    70.124635 %
# 3. operating_provider_license_number by     26.114227 %
# 4. other_provider_license_number by         96.957239 %
# .
# * For less than 20 % we drop rows. affected columns as follows:
# 1. health_service_area by                     0.124166 %
# 2. hospital_county  by                        0.124166 %
# 3. operating_certificate_number by            0.124166 %
# 4. facility_id by                             0.124166 %
# 5. zip_code__3_digits by                      0.188744 %
# 6. apr_severity_of_illness_description by     0.004777 %
# 7. apr_risk_of_mortality by                   0.004777 %
# 8. attending_provider_license_number by       0.124166 %
# ---
# * After checking info, unique, and value counts we found that:
#
# 1. zip_code__3_digits feature has strange value 'OOS' repeated 67135 times which refer to Out of State zip codes replaced it with 005 to indicate out of state. Also, changing dtype to numeric.
# 2. gender feature have strange value 'U' repeated 39 times these values raws dropped.
# 3. length_of_stay feature has '120 +', we create new feature for over_120_stay then I treated all entries '120 +' in length of stay as 120. also dtype changed to numerical.
# 4. discharge_year feature has only 2015 value. it will not be useful so drop it.
# 5. attending_provider_license_number feature it is not useful and we drop it.
# 6. abortion_edit_indicator feature have only 'N' value. it will not be useful we drop it.
# 7. total_charges feature have Dollar signe. Sign removed and replaced dtype to numerical.
# 8. total_costs feature have Dollar signe. Sign removed and replaced dtype to numerical.
# ---
# * Finding 10,598 duplicated record the dealing with them done by dropping them and reset the index.
# ---
# * Saving file as cleaned_data.csv after cleaning process for next Analysis steps.
